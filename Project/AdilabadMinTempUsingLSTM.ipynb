# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
# %matplotlib inline

# %%
dataset_train = pd.read_excel("D:\\DATASETS\\GOAT.xlsx")

# %%
dataset_train.head()
# Out:
#    district       date  rain  temp_min  temp_max  humidity_min  humidity_max  \
# 0  Adilabad 2018-01-01   0.0      10.4      29.7          41.8          83.8
# 1  Adilabad 2018-01-02   0.0      11.2      34.8          29.8          74.6
# 2  Adilabad 2018-01-03   0.0      17.3      38.0          31.8          71.5
# 3  Adilabad 2018-01-04   0.0      27.3      41.0          24.9          75.6
# 4  Adilabad 2018-01-05   0.0      28.7      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
del dataset_train['district']

# %%
f_col=dataset_train.pop('temp_min')

# %%
dataset_train.insert(1,'temp_min',f_col)

# %%
dataset_train.head(5)
# Out:
#         date  temp_min  rain  temp_max  humidity_min  humidity_max  \
# 0 2018-01-01      10.4   0.0      29.7          41.8          83.8
# 1 2018-01-02      11.2   0.0      34.8          29.8          74.6
# 2 2018-01-03      17.3   0.0      38.0          31.8          71.5
# 3 2018-01-04      27.3   0.0      41.0          24.9          75.6
# 4 2018-01-05      28.7   0.0      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
dataset_train.tail()
# Out:
#            date  temp_min  rain  temp_max  humidity_min  humidity_max  \
# 1729 2022-09-26      22.6   0.0      32.7          62.2         100.0
# 1730 2022-09-27      23.9   2.3      33.0          65.2          98.8
# 1731 2022-09-28      22.6   4.0      32.5          70.6         100.0
# 1732 2022-09-29      23.4   1.0      31.6          71.0         100.0
# 1733 2022-09-30      22.1   0.0      30.2          75.8         100.0
#
#       wind_speed_max  wind_speed_min
# 1729             0.0             9.4
# 1730             0.0            12.9
# 1731             0.0             7.1
# 1732             0.0             9.9
# 1733             0.0             6.5

# %%
avg=dataset_train['wind_speed_min'].mean()
dataset_train['wind_speed_min'].replace(np.nan,avg,inplace=True)

# %%
# Select features (columns) to be involved intro training and predictions
cols = list(dataset_train)[1:]

# Extract dates (will be used in visualization)
datelist_train = list(dataset_train['date'])

# %%
print('Training set shape == {}'.format(dataset_train.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(cols))
# Out:
# Training set shape == (1734, 8)
# All timestamps == 1734
# Featured selected: ['temp_min', 'rain', 'temp_max', 'humidity_min', 'humidity_max', 'wind_speed_max', 'wind_speed_min']

# %%
dataset_train = dataset_train[cols].astype(str)
dataset_train = dataset_train.astype(float)
training_set = dataset_train.values
print('Shape of training set == {}.'.format(training_set.shape))
# Out:
# Shape of training set == (1734, 7).

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
training_set_scaled = sc.fit_transform(training_set)

sc_predict = StandardScaler()
sc_predict.fit_transform(training_set[:, 0:1])
# Out:
# array([[-1.7996828 ],
#        [-1.66934889],
#        [-0.67555282],
#        ...,
#        [ 0.18790933],
#        [ 0.31824324],
#        [ 0.10645063]])

# %%
# Creating a data structure with 90 timestamps and 1 output
X_train = []
y_train = []

n_future = 365   # Number of days we want top predict into the future
n_past = 550     # Number of past days we want to use to predict the future

for i in range(n_past, len(training_set_scaled) - n_future +1):
    X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
    y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (820, 550, 6).
# y_train shape == (820, 1).

# %%
# Import Libraries and packages from Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
# Initializing the Neural Network based on LSTM
model = Sequential()

# Adding 1st LSTM layer
model.add(LSTM(units=64, return_sequences=True, input_shape=(n_past, dataset_train.shape[1]-1)))

# Adding 2nd LSTM layer
model.add(LSTM(units=10, return_sequences=False))

# Adding Dropout
model.add(Dropout(0.25))

# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# %%
# %%time
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

history = model.fit(X_train, y_train, shuffle=True, epochs=30, callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Epoch 1/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5762
# Epoch 1: val_loss improved from inf to 0.14079, saving model to weights.h5
# 3/3 [==============================] - 38s 7s/step - loss: 0.5762 - val_loss: 0.1408 - lr: 0.0100
# Epoch 2/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3227
# Epoch 2: val_loss improved from 0.14079 to 0.13482, saving model to weights.h5
# 3/3 [==============================] - 15s 5s/step - loss: 0.3227 - val_loss: 0.1348 - lr: 0.0100
# Epoch 3/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3086
# Epoch 3: val_loss improved from 0.13482 to 0.12576, saving model to weights.h5
# 3/3 [==============================] - 17s 6s/step - loss: 0.3086 - val_loss: 0.1258 - lr: 0.0100
# Epoch 4/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2736
# Epoch 4: val_loss improved from 0.12576 to 0.12455, saving model to weights.h5
# 3/3 [==============================] - 14s 5s/step - loss: 0.2736 - val_loss: 0.1245 - lr: 0.0100
# Epoch 5/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2696
# Epoch 5: val_loss improved from 0.12455 to 0.10636, saving model to weights.h5
# 3/3 [==============================] - 14s 5s/step - loss: 0.2696 - val_loss: 0.1064 - lr: 0.0100
# Epoch 6/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2547
# Epoch 6: val_loss improved from 0.10636 to 0.10256, saving model to weights.h5
# 3/3 [==============================] - 12s 4s/step - loss: 0.2547 - val_loss: 0.1026 - lr: 0.0100
# Epoch 7/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2504
# Epoch 7: val_loss improved from 0.10256 to 0.10012, saving model to weights.h5
# 3/3 [==============================] - 12s 4s/step - loss: 0.2504 - val_loss: 0.1001 - lr: 0.0100
# Epoch 8/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2460
# Epoch 8: val_loss did not improve from 0.10012
# 3/3 [==============================] - 14s 5s/step - loss: 0.2460 - val_loss: 0.1294 - lr: 0.0100
# Epoch 9/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2402
# Epoch 9: val_loss improved from 0.10012 to 0.08516, saving model to weights.h5
# 3/3 [==============================] - 14s 5s/step - loss: 0.2402 - val_loss: 0.0852 - lr: 0.0100
# Epoch 10/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2695
# Epoch 10: val_loss did not improve from 0.08516
# 3/3 [==============================] - 13s 4s/step - loss: 0.2695 - val_loss: 0.0869 - lr: 0.0100
# Epoch 11/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2216
# Epoch 11: val_loss did not improve from 0.08516
# 3/3 [==============================] - 14s 5s/step - loss: 0.2216 - val_loss: 0.0922 - lr: 0.0100
# Epoch 12/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2212
# Epoch 12: val_loss did not improve from 0.08516
# 3/3 [==============================] - 14s 5s/step - loss: 0.2212 - val_loss: 0.1113 - lr: 0.0100
# Epoch 13/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2197
# Epoch 13: val_loss did not improve from 0.08516
# 3/3 [==============================] - 14s 5s/step - loss: 0.2197 - val_loss: 0.1149 - lr: 0.0100
# Epoch 14/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2035
# Epoch 14: val_loss did not improve from 0.08516
# 3/3 [==============================] - 15s 5s/step - loss: 0.2035 - val_loss: 0.1097 - lr: 0.0100
# Epoch 15/30
# 3/3 [==============================] - ETA: 0s - loss: 0.1899
# Epoch 15: val_loss did not improve from 0.08516
# 3/3 [==============================] - 14s 5s/step - loss: 0.1899 - val_loss: 0.0982 - lr: 0.0100
# Epoch 16/30
# 3/3 [==============================] - ETA: 0s - loss: 0.1859
# Epoch 16: val_loss did not improve from 0.08516
# 3/3 [==============================] - 14s 5s/step - loss: 0.1859 - val_loss: 0.1034 - lr: 0.0100
# Epoch 17/30
# 3/3 [==============================] - ETA: 0s - loss: 0.1771
# Epoch 17: val_loss did not improve from 0.08516
# 3/3 [==============================] - 15s 5s/step - loss: 0.1771 - val_loss: 0.1096 - lr: 0.0100
# Epoch 18/30
# 3/3 [==============================] - ETA: 0s - loss: 0.1589
# Epoch 18: val_loss did not improve from 0.08516
# 3/3 [==============================] - 14s 5s/step - loss: 0.1589 - val_loss: 0.1137 - lr: 0.0100
# Epoch 19/30
# 3/3 [==============================] - ETA: 0s - loss: 0.1602
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 19: val_loss did not improve from 0.08516
# 3/3 [==============================] - 15s 5s/step - loss: 0.1602 - val_loss: 0.1126 - lr: 0.0100
# Epoch 19: early stopping
# CPU times: total: 10min 51s
# Wall time: 4min 51s

# %%
# Generate list of sequence of days for predictions
datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()

# Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
datelist_future_ = []
for this_timestamp in datelist_future:
    datelist_future_.append(this_timestamp.date())

# %%
# Perform predictions
predictions_future = model.predict(X_train[-n_future:])

predictions_train = model.predict(X_train[n_past:])
# Out:
# 12/12 [==============================] - 9s 435ms/step
# 9/9 [==============================] - 4s 402ms/step

# %%
def datetime_to_timestamp(x):
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')

# %%
y_pred_future = sc_predict.inverse_transform(predictions_future)
y_pred_train = sc_predict.inverse_transform(predictions_train)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['temp_min']).set_index(pd.Series(datelist_future))
PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['temp_min']).set_index(pd.Series(datelist_train[2 *n_past +n_future -1:]))

# %%
PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)

PREDICTION_TRAIN
# Out:
#              temp_min
# 2022-01-04  14.975846
# 2022-01-05  14.843448
# 2022-01-06  14.893841
# 2022-01-07  15.085923
# 2022-01-08  15.337664
# ...               ...
# 2022-09-26  25.178810
# 2022-09-27  25.015837
# 2022-09-28  24.748253
# 2022-09-29  24.903406
# 2022-09-30  24.922064
#
# [270 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(dataset_train['temp_min'][1464:],PREDICTION_TRAIN))
# Out:
# 2.1995692031021234

# %%
PREDICTIONS_FUTURE
# Out:
#              temp_min
# 2022-09-30  24.629545
# 2022-10-01  24.524811
# 2022-10-02  24.485254
# 2022-10-03  24.302292
# 2022-10-04  23.973810
# ...               ...
# 2023-09-25  25.178810
# 2023-09-26  25.015837
# 2023-09-27  24.748253
# 2023-09-28  24.903406
# 2023-09-29  24.922064
#
# [365 rows x 1 columns]

# %%
dataset_train.index=datelist_train

# %%
dataset_train.head(5)
# Out:
#             temp_min  rain  temp_max  humidity_min  humidity_max  \
# 2018-01-01      10.4   0.0      29.7          41.8          83.8
# 2018-01-02      11.2   0.0      34.8          29.8          74.6
# 2018-01-03      17.3   0.0      38.0          31.8          71.5
# 2018-01-04      27.3   0.0      41.0          24.9          75.6
# 2018-01-05      28.7   0.0      43.2          27.7          48.9
#
#             wind_speed_max  wind_speed_min
# 2018-01-01             0.0             5.7
# 2018-01-02             0.0             4.8
# 2018-01-03             0.0             3.4
# 2018-01-04             0.0             7.7
# 2018-01-05             0.0            13.5

# %%
ax=dataset_train['temp_min']["2022-01-04":"2022-09-30"].plot(figsize=(18,7))
PREDICTION_TRAIN.plot(ax=ax)
plt.legend(['Actual','Predicted'],prop={'size':15})
plt.grid()
plt.show()

# %%
PREDICTIONS_FUTURE.plot(color='green',figsize=(18,6))
plt.xlabel("Date")
plt.ylabel("Min Temp")
plt.legend(['Future Forecast'],prop={'size':15})
plt.grid()
plt.show()

# %%
ax=dataset_train['temp_min']["2022-01-04":"2022-09-30"].plot(figsize=(18,7))
PREDICTION_TRAIN.plot(ax=ax)
PREDICTIONS_FUTURE.plot(ax=ax)
plt.legend(['Actual','Predicted','Future'],prop={'size':15})
plt.grid()
plt.show()
