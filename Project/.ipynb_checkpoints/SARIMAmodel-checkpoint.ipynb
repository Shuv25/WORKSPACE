# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import itertools
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("D:\\DATASETS\\Electric_Production.csv",parse_dates=['date'],index_col='date')

# %%
df.head()
# Out:
#                Bill
# date
# 1985-01-01  72.5052
# 1985-02-01  70.6720
# 1985-03-01  62.4502
# 1985-04-01  57.4714
# 1985-05-01  55.3151

# %%
df.plot(figsize=(18,7))
plt.xlabel("Date")
plt.ylabel("Bill")
plt.grid()
plt.show()

# %%
train=df[:len(df)*80//100]

# %%
train.tail()
# Out:
#                 Bill
# date
# 2011-01-01  119.4880
# 2011-02-01  107.3753
# 2011-03-01   99.1028
# 2011-04-01   89.3583
# 2011-05-01   90.0698

# %%
test=df[len(df)*80//100:]
