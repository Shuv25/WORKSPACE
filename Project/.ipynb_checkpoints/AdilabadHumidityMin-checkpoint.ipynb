# 2020-10-31        1.722581        0.035484
# 2020-11-30        1.523333        0.000000
# 2020-12-31        1.877419        0.000000
# 2021-01-31        0.000000        1.819355
# 2021-02-28        0.003571        2.057143
# 2021-03-31        0.048387        3.293548
# 2021-04-30        0.496667        7.403333
# 2021-05-31        0.480645        2.829032
# 2021-06-30        0.143333        3.513333
# 2021-07-31        0.054839        2.183871
# 2021-08-31        0.158065        9.548387
# 2021-09-30        0.273333       10.263333
# 2021-10-31        0.000000        8.696774
# 2021-11-30        0.000000        0.000000
# 2021-12-31        0.070968        9.345161
# 2022-01-31        0.029032        9.512903
# 2022-02-28        0.000000       64.857143
# 2022-03-31        0.106452       12.070968
# 2022-04-30        0.610000       13.450000
# 2022-05-31        0.245161       15.003226
# 2022-06-30        0.240000       12.333333
# 2022-07-31        0.422581        8.803226
# 2022-08-31        0.396774       10.309677
# 2022-09-30        0.250000        9.466667

# %%
df['humidity_min'].plot(figsize=(18,7))
plt.show()

# %%
adfuller(df['humidity_min'])
# Out:
# (-2.7626150397294356,
#  0.06381555721419009,
#  8,
#  48,
#  {'1%': -3.5745892596209488,
#   '5%': -2.9239543084490744,
#   '10%': -2.6000391840277777},
#  343.14002796011323)

# %%
'''plot_pacf(df['humidity_min'])
plot_acf(df['humidity_min'])
plt.show()'''
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 plot_pacf(df['humidity_min'])
#       2 plot_acf(df['humidity_min'])
#       3 plt.show()
#
# NameError: name 'plot_pacf' is not defined

# %%
df_diff=df['humidity_min'].diff().diff(12).dropna()

# %%
adfuller(df_diff)
# Out:
# (-4.94469648299635,
#  2.8521738862344873e-05,
#  2,
#  41,
#  {'1%': -3.60098336718852,
#   '5%': -2.9351348158036012,
#   '10%': -2.6059629803688282},
#  240.16319263681157)

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_pacf(df_diff)
plot_acf(df_diff)
plt.show()

# %%
train=df[:len(df)*80//100]
test=df[len(df)*80//100:]

# %%
import itertools

# %%
'''p = range(0, 3)
d = range(1,2)
q = range(0, 4)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df_diff,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue'''

# %%
model=sm.tsa.statespace.SARIMAX(train['humidity_min'],order=(0, 1, 1),seasonal_order=(0, 1, 1, 12))

# %%
model_fit=model.fit()

# %%
predictions=model_fit.predict(start=test.index[0],end=test.index[-1])

# %%
test['humidity_min'].plot(figsize=(18,7),legend=True)
predictions.plot(legend=True)
plt.grid()

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(test['humidity_min'],predictions))
# Out:
# 15.09959296441465

# %%
future=pd.DataFrame(pd.date_range("2022-10-01","2023-09-30",freq='MS'),columns=['date'])

# %%
future.set_index('date',inplace=True)

# %%
Forecast=model_fit.predict(start=future.index[0],end=future.index[-1])

# %%
ax=df['humidity_min'].plot(label="Past Data")
Forecast.plot(ax=ax,label="Predicted Future data",figsize=(18,7))
plt.xlabel("Date")
plt.ylabel("Min Humidity")
plt.legend(["Past","Predicted Future Data"])
plt.grid()
plt.show()
