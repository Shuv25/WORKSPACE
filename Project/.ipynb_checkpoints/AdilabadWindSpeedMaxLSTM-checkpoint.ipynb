# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
# %matplotlib inline

# %%
dataset_train = pd.read_excel("D:\\DATASETS\\GOAT.xlsx")

# %%
dataset_train.head()
# Out:
#    district       date  rain  temp_min  temp_max  humidity_min  humidity_max  \
# 0  Adilabad 2018-01-01   0.0      10.4      29.7          41.8          83.8
# 1  Adilabad 2018-01-02   0.0      11.2      34.8          29.8          74.6
# 2  Adilabad 2018-01-03   0.0      17.3      38.0          31.8          71.5
# 3  Adilabad 2018-01-04   0.0      27.3      41.0          24.9          75.6
# 4  Adilabad 2018-01-05   0.0      28.7      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
del dataset_train['district']

# %%
dataset_train.drop(columns=['temp_min','temp_max'],axis=1,inplace=True)

# %%
f_col=dataset_train.pop('wind_speed_max')

# %%
dataset_train.insert(1,'wind_speed_max',f_col)

# %%
dataset_train.head(5)
# Out:
#         date  wind_speed_max  rain  humidity_min  humidity_max  wind_speed_min
# 0 2018-01-01             0.0   0.0          41.8          83.8             5.7
# 1 2018-01-02             0.0   0.0          29.8          74.6             4.8
# 2 2018-01-03             0.0   0.0          31.8          71.5             3.4
# 3 2018-01-04             0.0   0.0          24.9          75.6             7.7
# 4 2018-01-05             0.0   0.0          27.7          48.9            13.5

# %%
mode=dataset_train['wind_speed_min'].value_counts().idxmax()
dataset_train['wind_speed_min'].replace(np.nan,mode,inplace=True)

# %%
# Select features (columns) to be involved intro training and predictions
cols = list(dataset_train)[1:]

# Extract dates (will be used in visualization)
datelist_train = list(dataset_train['date'])

# %%
print('Training set shape == {}'.format(dataset_train.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(cols))
# Out:
# Training set shape == (1734, 6)
# All timestamps == 1734
# Featured selected: ['wind_speed_max', 'rain', 'humidity_min', 'humidity_max', 'wind_speed_min']

# %%
dataset_train = dataset_train[cols].astype(str)
dataset_train = dataset_train.astype(float)
training_set = dataset_train.values
print('Shape of training set == {}.'.format(training_set.shape))
# Out:
# Shape of training set == (1734, 5).

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
training_set_scaled = sc.fit_transform(training_set)

sc_predict = StandardScaler()
sc_predict.fit_transform(training_set[:, 0:1])
# Out:
# array([[-0.51808111],
#        [-0.51808111],
#        [-0.51808111],
#        ...,
#        [-0.51808111],
#        [-0.51808111],
#        [-0.51808111]])

# %%
# Creating a data structure with 90 timestamps and 1 output
X_train = []
y_train = []

n_future = 365   # Number of days we want top predict into the future
n_past = 550     # Number of past days we want to use to predict the future

for i in range(n_past, len(training_set_scaled) - n_future +1):
    X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
    y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (820, 550, 4).
# y_train shape == (820, 1).

# %%
# Import Libraries and packages from Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
# Initializing the Neural Network based on LSTM
model = Sequential()

# Adding 1st LSTM layer
model.add(LSTM(units=64, return_sequences=True, input_shape=(n_past, dataset_train.shape[1]-1)))

# Adding 2nd LSTM layer
model.add(LSTM(units=10, return_sequences=False))

# Adding Dropout
model.add(Dropout(0.25))

# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# %%
# %%time
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

history = model.fit(X_train, y_train, shuffle=True, epochs=30, callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Epoch 1/30
# 3/3 [==============================] - ETA: 0s - loss: 0.6698
# Epoch 1: val_loss improved from inf to 1.10298, saving model to weights.h5
# 3/3 [==============================] - 25s 5s/step - loss: 0.6698 - val_loss: 1.1030 - lr: 0.0100
# Epoch 2/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3711
# Epoch 2: val_loss did not improve from 1.10298
# 3/3 [==============================] - 13s 4s/step - loss: 0.3711 - val_loss: 1.8452 - lr: 0.0100
# Epoch 3/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3778
# Epoch 3: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.3778 - val_loss: 1.4450 - lr: 0.0100
# Epoch 4/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3278
# Epoch 4: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.3278 - val_loss: 1.4364 - lr: 0.0100
# Epoch 5/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3246
# Epoch 5: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.3246 - val_loss: 1.7114 - lr: 0.0100
# Epoch 6/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3354
# Epoch 6: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.3354 - val_loss: 2.3776 - lr: 0.0100
# Epoch 7/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3071
# Epoch 7: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.3071 - val_loss: 2.4449 - lr: 0.0100
# Epoch 8/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3098
# Epoch 8: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.3098 - val_loss: 1.9666 - lr: 0.0100
# Epoch 9/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2930
# Epoch 9: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.2930 - val_loss: 2.7001 - lr: 0.0100
# Epoch 10/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2894
# Epoch 10: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.2894 - val_loss: 2.4734 - lr: 0.0100
# Epoch 11/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3055
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.004999999888241291.
#
# Epoch 11: val_loss did not improve from 1.10298
# 3/3 [==============================] - 11s 4s/step - loss: 0.3055 - val_loss: 2.6721 - lr: 0.0100
# Epoch 11: early stopping
# CPU times: total: 5min 18s
# Wall time: 2min 16s

# %%
# Generate list of sequence of days for predictions
datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()

# Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
datelist_future_ = []
for this_timestamp in datelist_future:
    datelist_future_.append(this_timestamp.date())

# %%
# Perform predictions
predictions_future = model.predict(X_train[-n_future:])

predictions_train = model.predict(X_train[n_past:])
# Out:
# 12/12 [==============================] - 6s 286ms/step
# 9/9 [==============================] - 3s 292ms/step

# %%
def datetime_to_timestamp(x):
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')

# %%
y_pred_future = sc_predict.inverse_transform(predictions_future)
y_pred_train = sc_predict.inverse_transform(predictions_train)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['wind_speed_max']).set_index(pd.Series(datelist_future))
PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['wind_speed_max']).set_index(pd.Series(datelist_train[2 *n_past +n_future -1:]))

# %%
PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)

PREDICTION_TRAIN
# Out:
#             wind_speed_max
# 2022-01-04        0.006656
# 2022-01-05        0.005351
# 2022-01-06        0.007272
# 2022-01-07        0.010117
# 2022-01-08        0.019086
# ...                    ...
# 2022-09-26        2.831150
# 2022-09-27        2.814783
# 2022-09-28        2.661711
# 2022-09-29        2.643207
# 2022-09-30        2.687832
#
# [270 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(dataset_train['wind_speed_max'][1464:],PREDICTION_TRAIN))
# Out:
# 1.7000709521472248

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(dataset_train['wind_speed_max'][1464:],PREDICTION_TRAIN)
# Out:
# 1.2481855830218191

# %%
PREDICTIONS_FUTURE
# Out:
#             wind_speed_max
# 2022-09-30        0.065717
# 2022-10-01        0.065162
# 2022-10-02        0.078247
# 2022-10-03        0.117240
# 2022-10-04        0.108965
# ...                    ...
# 2023-09-25        2.831150
# 2023-09-26        2.814783
# 2023-09-27        2.661711
# 2023-09-28        2.643207
# 2023-09-29        2.687832
#
# [365 rows x 1 columns]

# %%
dataset_train.index=datelist_train

# %%
dataset_train.head(5)
# Out:
#             wind_speed_max  rain  humidity_min  humidity_max  wind_speed_min
# 2018-01-01             0.0   0.0          41.8          83.8             5.7
# 2018-01-02             0.0   0.0          29.8          74.6             4.8
# 2018-01-03             0.0   0.0          31.8          71.5             3.4
# 2018-01-04             0.0   0.0          24.9          75.6             7.7
# 2018-01-05             0.0   0.0          27.7          48.9            13.5

# %%
ax=dataset_train['wind_speed_max']["2022-01-04":"2022-09-30"].plot(figsize=(18,7))
PREDICTION_TRAIN.plot(ax=ax)
plt.legend(['Actual','Predicted'],prop={'size':15})
plt.grid()
plt.show()

# %%
PREDICTIONS_FUTURE.plot(color='green',figsize=(18,6))
plt.xlabel("Date")
plt.ylabel("Max Wind Speed")
plt.legend(['Future Forecast'],prop={'size':15})
plt.grid()
plt.show()

# %%
PREDICTIONS_FUTURE.to_excel("AdilabadMaxWindSpeedUsingLSTM.xlsx")

# %%
ax=dataset_train['wind_speed_max']["2022-01-04":"2022-09-30"].plot(figsize=(18,7))
PREDICTION_TRAIN.plot(ax=ax)
PREDICTIONS_FUTURE.plot(ax=ax)
plt.legend(['Actual','Predicted','Future'],prop={'size':15})
plt.grid()
plt.show()
