# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import itertools
import warnings
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("D:\\DATASETS\\GOAT.xlsx",parse_dates=['date'])

# %%
df.head()
# Out:
#    district       date  rain  temp_min  temp_max  humidity_min  humidity_max  \
# 0  Adilabad 2018-01-01   0.0      10.4      29.7          41.8          83.8
# 1  Adilabad 2018-01-02   0.0      11.2      34.8          29.8          74.6
# 2  Adilabad 2018-01-03   0.0      17.3      38.0          31.8          71.5
# 3  Adilabad 2018-01-04   0.0      27.3      41.0          24.9          75.6
# 4  Adilabad 2018-01-05   0.0      28.7      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
df=df.resample('M',on='date').mean()

# %%
df.head()
# Out:
#                 rain   temp_min   temp_max  humidity_min  humidity_max  \
# date
# 2018-01-31  1.151613  15.241935  33.187097     40.567742     79.909677
# 2018-02-28  1.350000  19.053571  34.964286     43.907143     80.328571
# 2018-03-31  0.370968  21.493548  36.445161     39.716129     72.570968
# 2018-04-30  0.093333  24.910000  38.920000     37.963333     68.506667
# 2018-05-31  1.532258  26.441935  40.070968     39.064516     71.164516
#
#             wind_speed_max  wind_speed_min
# date
# 2018-01-31        0.051613        6.896774
# 2018-02-28        0.007143        6.846429
# 2018-03-31        0.003226        6.293548
# 2018-04-30        0.030000        8.373333
# 2018-05-31        0.296774        9.967742

# %%
df['humidity_max'].plot(figsize=(18,7))
plt.show()

# %%
adfuller(df['humidity_max'])
# Out:
# (-1.0307017542138468,
#  0.7419025227316292,
#  11,
#  45,
#  {'1%': -3.584828853223594,
#   '5%': -2.9282991495198907,
#   '10%': -2.6023438271604937},
#  357.6548081793841)

# %%
df['shift']=df['humidity_max'].shift()
df['shiftdiff']=df.humidity_max-df['shift']

# %%
adfuller(df['shiftdiff'].dropna())
# Out:
# (-2.773199964028911,
#  0.06220510991540889,
#  11,
#  44,
#  {'1%': -3.5885733964124715,
#   '5%': -2.929885661157025,
#   '10%': -2.6031845661157025},
#  344.2031627513925)

# %%
df['shift2']=df['humidity_max'].shift(2)
df['shiftdiff2']=df.humidity_max-df['shift2']

# %%
adfuller(df['shiftdiff2'].dropna())
# Out:
# (-2.7957605316643965,
#  0.058881902397316895,
#  10,
#  44,
#  {'1%': -3.5885733964124715,
#   '5%': -2.929885661157025,
#   '10%': -2.6031845661157025},
#  334.59268567901614)

# %%
df['shift3']=df['humidity_max'].shift(3)
df['shiftdiff3']=df.humidity_max-df['shift3']

# %%
adfuller(df['shiftdiff3'].dropna())
# Out:
# (-2.8174145168917533,
#  0.05582896311824388,
#  9,
#  44,
#  {'1%': -3.5885733964124715,
#   '5%': -2.929885661157025,
#   '10%': -2.6031845661157025},
#  327.5808595398332)

# %%
df['shift6']=df['humidity_max'].shift(6)
df['shiftdiff6']=df.humidity_max-df['shift6']

# %%
adfuller(df['shiftdiff6'].dropna())
# Out:
# (-2.0363973729288096,
#  0.27084557897799616,
#  7,
#  43,
#  {'1%': -3.5925042342183704,
#   '5%': -2.931549768951162,
#   '10%': -2.60406594375338},
#  291.9622566641831)

# %%
df['shift4']=df['humidity_max'].shift(4)
df['shiftdiff4']=df.humidity_max-df['shift4']

# %%
adfuller(df['shiftdiff4'].dropna())
# Out:
# (-1.9731759681241487,
#  0.2984569105189651,
#  9,
#  43,
#  {'1%': -3.5925042342183704,
#   '5%': -2.931549768951162,
#   '10%': -2.60406594375338},
#  317.43751475601937)

# %%
df['shiftdiff3'].plot(figsize=(18,7))
plt.show()

# %%
df_diff=df['humidity_max'].diff().diff(12).dropna()

# %%
adfuller(df_diff)
# Out:
# (-6.179770307462848,
#  6.497778232618223e-08,
#  1,
#  42,
#  {'1%': -3.596635636000432,
#   '5%': -2.933297331821618,
#   '10%': -2.6049909750566895},
#  245.1241666890424)

# %%
df_diff3=df['humidity_max'].diff(12).dropna()
adfuller(df_diff3)
# Out:
# (-3.496226581119135,
#  0.008084533938486866,
#  10,
#  34,
#  {'1%': -3.639224104416853,
#   '5%': -2.9512301791166293,
#   '10%': -2.614446989619377},
#  247.5348135638658)

# %%
plot_pacf(df_diff3)
plot_acf(df_diff3)
plt.show()

# %%
p = range(0, 3)
d = range(1,2)
q = range(0, 5)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

# %%
for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df_diff3,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# Optimization terminated successfully.
#          Current function value: 3.000942
#          Iterations: 2
#          Function evaluations: 35
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:272.0848214425505
# Optimization terminated successfully.
#          Current function value: 2.975036
#          Iterations: 2
#          Function evaluations: 54
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:271.75327431704244
# Optimization terminated successfully.
#          Current function value: 2.968038
#          Iterations: 3
#          Function evaluations: 101
# ARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:273.12339497787355
# Optimization terminated successfully.
#          Current function value: 2.968038
#          Iterations: 2
#          Function evaluations: 86
# ARIMA(0, 1, 0)x(0, 1, 3, 12)12 - AIC:275.12340566775674
# Optimization terminated successfully.
#          Current function value: 2.968037
#          Iterations: 3
#          Function evaluations: 172
# ARIMA(0, 1, 0)x(0, 1, 4, 12)12 - AIC:277.12328629778784
# Optimization terminated successfully.
#          Current function value: 2.968316
#          Iterations: 3
#          Function evaluations: 71
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:271.1483968863127
# Optimization terminated successfully.
#          Current function value: 2.968179
#          Iterations: 2
#          Function evaluations: 68
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:273.1360987121357
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 2
#          Function evaluations: 91
# ARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:275.12318913416317
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 2
#          Function evaluations: 110
# ARIMA(0, 1, 0)x(1, 1, 3, 12)12 - AIC:277.12318051274605
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 2
#          Function evaluations: 135
# ARIMA(0, 1, 0)x(1, 1, 4, 12)12 - AIC:279.12318362391557
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 3
#          Function evaluations: 100
# ARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:273.1231597451127
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 2
#          Function evaluations: 88
# ARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:275.12316027494757
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 2
#          Function evaluations: 113
# ARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:277.123158743173
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 2
#          Function evaluations: 131
# ARIMA(0, 1, 0)x(2, 1, 3, 12)12 - AIC:279.12315839126603
# Optimization terminated successfully.
#          Current function value: 2.968035
#          Iterations: 2
#          Function evaluations: 155
# ARIMA(0, 1, 0)x(2, 1, 4, 12)12 - AIC:281.1231582313061
# Optimization terminated successfully.
#          Current function value: 2.967571
#          Iterations: 2
#          Function evaluations: 43
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:271.08142916878785
# Optimization terminated successfully.
#          Current function value: 2.929605
#          Iterations: 3
#          Function evaluations: 109
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:269.6644526384263
# Optimization terminated successfully.
#          Current function value: 2.917816
#          Iterations: 3
#          Function evaluations: 134
# ARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:270.6034436774586
# Optimization terminated successfully.
#          Current function value: 2.917788
#          Iterations: 3
#          Function evaluations: 173
# ARIMA(0, 1, 1)x(0, 1, 3, 12)12 - AIC:272.60096372191913
# Optimization terminated successfully.
#          Current function value: 2.917785
#          Iterations: 3
#          Function evaluations: 204
# ARIMA(0, 1, 1)x(0, 1, 4, 12)12 - AIC:274.6006397224264
# Optimization terminated successfully.
#          Current function value: 2.917816
#          Iterations: 3
#          Function evaluations: 96
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:268.6034812940246
# Optimization terminated successfully.
#          Current function value: 2.917988
#          Iterations: 3
#          Function evaluations: 137
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:270.61889965202704
# Optimization terminated successfully.
#          Current function value: 2.917784
#          Iterations: 3
#          Function evaluations: 162
# ARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:272.6005749211365
# Optimization terminated successfully.
#          Current function value: 2.917784
#          Iterations: 3
#          Function evaluations: 192
# ARIMA(0, 1, 1)x(1, 1, 3, 12)12 - AIC:274.60057941564406
# Optimization terminated successfully.
#          Current function value: 2.917784
#          Iterations: 3
#          Function evaluations: 227
# ARIMA(0, 1, 1)x(1, 1, 4, 12)12 - AIC:276.60058068981266
# Optimization terminated successfully.
#          Current function value: 2.917784
#          Iterations: 3
#          Function evaluations: 125
# ARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:270.60053704489644
# Optimization terminated successfully.
#          Current function value: 2.917783
#          Iterations: 3
#          Function evaluations: 163
# ARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:272.60048957097445
# Optimization terminated successfully.
#          Current function value: 2.917783
#          Iterations: 3
#          Function evaluations: 192
# ARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:274.60048225421406
# Optimization terminated successfully.
#          Current function value: 2.917783
#          Iterations: 3
#          Function evaluations: 224
# ARIMA(0, 1, 1)x(2, 1, 3, 12)12 - AIC:276.6004816966798
# Optimization terminated successfully.
#          Current function value: 2.917783
#          Iterations: 3
#          Function evaluations: 270
# ARIMA(0, 1, 1)x(2, 1, 4, 12)12 - AIC:278.60048186898115
# Optimization terminated successfully.
#          Current function value: 2.924566
#          Iterations: 3
#          Function evaluations: 163
# ARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:269.21095069709384
# Optimization terminated successfully.
#          Current function value: 2.910778
#          Iterations: 3
#          Function evaluations: 184
# ARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:269.9700194546205
# Optimization terminated successfully.
#          Current function value: 2.880308
#          Iterations: 5
#          Function evaluations: 328
# ARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:269.22774209042774
# Optimization terminated successfully.
#          Current function value: 2.880300
#          Iterations: 5
#          Function evaluations: 373
# ARIMA(0, 1, 2)x(0, 1, 3, 12)12 - AIC:271.22700854523146
# Optimization terminated successfully.
#          Current function value: 2.880352
#          Iterations: 3
#          Function evaluations: 272
# ARIMA(0, 1, 2)x(0, 1, 4, 12)12 - AIC:273.23169457023903
# Optimization terminated successfully.
#          Current function value: 2.916108
#          Iterations: 2
#          Function evaluations: 89
# ARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:270.44974431709346
# Optimization terminated successfully.
#          Current function value: 2.883608
#          Iterations: 8
#          Function evaluations: 492
# ARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:269.52470412061143
# Optimization terminated successfully.
#          Current function value: 2.880525
#          Iterations: 3
#          Function evaluations: 241
# ARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:271.24725910014354
# Optimization terminated successfully.
#          Current function value: 2.880505
#          Iterations: 3
#          Function evaluations: 277
# ARIMA(0, 1, 2)x(1, 1, 3, 12)12 - AIC:273.245488235242
# Optimization terminated successfully.
#          Current function value: 2.880326
#          Iterations: 3
#          Function evaluations: 306
# ARIMA(0, 1, 2)x(1, 1, 4, 12)12 - AIC:275.229313210674
# Optimization terminated successfully.
#          Current function value: 2.914755
#          Iterations: 4
#          Function evaluations: 220
# ARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:272.32796700220314
# Optimization terminated successfully.
#          Current function value: 2.880325
#          Iterations: 3
#          Function evaluations: 228
# ARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:271.2292525908819
# Optimization terminated successfully.
#          Current function value: 2.880325
#          Iterations: 3
#          Function evaluations: 263
# ARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:273.22927881587253
# Optimization terminated successfully.
#          Current function value: 2.880326
#          Iterations: 3
#          Function evaluations: 298
# ARIMA(0, 1, 2)x(2, 1, 3, 12)12 - AIC:275.22929652184763
# Optimization terminated successfully.
#          Current function value: 2.880326
#          Iterations: 3
#          Function evaluations: 339
# ARIMA(0, 1, 2)x(2, 1, 4, 12)12 - AIC:277.22931984260066
# Optimization terminated successfully.
#          Current function value: 2.898374
#          Iterations: 4
#          Function evaluations: 168
# ARIMA(0, 1, 3)x(0, 1, 0, 12)12 - AIC:268.8536785400129
# Optimization terminated successfully.
#          Current function value: 2.883117
#          Iterations: 6
#          Function evaluations: 328
# ARIMA(0, 1, 3)x(0, 1, 1, 12)12 - AIC:269.4805674440281
# Optimization terminated successfully.
#          Current function value: 2.864164
#          Iterations: 8
#          Function evaluations: 506
# ARIMA(0, 1, 3)x(0, 1, 2, 12)12 - AIC:269.77473444239143
# Optimization terminated successfully.
#          Current function value: 2.864144
#          Iterations: 7
#          Function evaluations: 522
# ARIMA(0, 1, 3)x(0, 1, 3, 12)12 - AIC:271.7729886199855
# Optimization terminated successfully.
#          Current function value: 2.864125
#          Iterations: 7
#          Function evaluations: 608
# ARIMA(0, 1, 3)x(0, 1, 4, 12)12 - AIC:273.7712168206022
# Optimization terminated successfully.
#          Current function value: 2.876304
#          Iterations: 6
#          Function evaluations: 320
# ARIMA(0, 1, 3)x(1, 1, 0, 12)12 - AIC:268.8673909730045
# Optimization terminated successfully.
#          Current function value: 2.864920
#          Iterations: 8
#          Function evaluations: 510
# ARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:269.8428185655594
# Optimization terminated successfully.
#          Current function value: 2.864069
#          Iterations: 7
#          Function evaluations: 521
# ARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:271.7662444879457
# Optimization terminated successfully.
#          Current function value: 2.864406
#          Iterations: 6
#          Function evaluations: 499
# ARIMA(0, 1, 3)x(1, 1, 3, 12)12 - AIC:273.7965110039805
# Optimization terminated successfully.
#          Current function value: 2.864052
#          Iterations: 7
#          Function evaluations: 667
# ARIMA(0, 1, 3)x(1, 1, 4, 12)12 - AIC:275.7646655506496
# Optimization terminated successfully.
#          Current function value: 2.863913
#          Iterations: 4
#          Function evaluations: 250
# ARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:269.75220617732464
# Optimization terminated successfully.
#          Current function value: 2.864074
#          Iterations: 7
#          Function evaluations: 509
# ARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:271.7666579047277
# Optimization terminated successfully.
#          Current function value: 2.864074
#          Iterations: 7
#          Function evaluations: 583
# ARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:273.7666197046989
# Optimization terminated successfully.
#          Current function value: 2.864071
#          Iterations: 7
#          Function evaluations: 656
# ARIMA(0, 1, 3)x(2, 1, 3, 12)12 - AIC:275.76635419326817
# Optimization terminated successfully.
#          Current function value: 2.864070
#          Iterations: 7
#          Function evaluations: 738
# ARIMA(0, 1, 3)x(2, 1, 4, 12)12 - AIC:277.76627976019506
# Optimization terminated successfully.
#          Current function value: 2.880418
#          Iterations: 4
#          Function evaluations: 273
# ARIMA(0, 1, 4)x(0, 1, 0, 12)12 - AIC:269.23765396767226
# Optimization terminated successfully.
#          Current function value: 2.848570
#          Iterations: 5
#          Function evaluations: 333
# ARIMA(0, 1, 4)x(0, 1, 1, 12)12 - AIC:268.37130082579336
# Optimization terminated successfully.
#          Current function value: 2.829526
#          Iterations: 5
#          Function evaluations: 397
# ARIMA(0, 1, 4)x(0, 1, 2, 12)12 - AIC:268.6573006689665
# Optimization terminated successfully.
#          Current function value: 2.829495
#          Iterations: 5
#          Function evaluations: 440
# ARIMA(0, 1, 4)x(0, 1, 3, 12)12 - AIC:270.6545570288106
# Optimization terminated successfully.
#          Current function value: 2.829488
#          Iterations: 5
#          Function evaluations: 497
# ARIMA(0, 1, 4)x(0, 1, 4, 12)12 - AIC:272.6539103494657
# Optimization terminated successfully.
#          Current function value: 2.830950
#          Iterations: 4
#          Function evaluations: 312
# ARIMA(0, 1, 4)x(1, 1, 0, 12)12 - AIC:266.7854933997787
# Optimization terminated successfully.
#          Current function value: 2.829573
#          Iterations: 5
#          Function evaluations: 394
# ARIMA(0, 1, 4)x(1, 1, 1, 12)12 - AIC:268.66153815400315
# Optimization terminated successfully.
#          Current function value: 2.829494
#          Iterations: 5
#          Function evaluations: 435
# ARIMA(0, 1, 4)x(1, 1, 2, 12)12 - AIC:270.65441932229027
# Optimization terminated successfully.
#          Current function value: 2.829487
#          Iterations: 5
#          Function evaluations: 484
# ARIMA(0, 1, 4)x(1, 1, 3, 12)12 - AIC:272.65387433648914
# Optimization terminated successfully.
#          Current function value: 2.829488
#          Iterations: 5
#          Function evaluations: 534
# ARIMA(0, 1, 4)x(1, 1, 4, 12)12 - AIC:274.653901520515
# Optimization terminated successfully.
#          Current function value: 2.829481
#          Iterations: 4
#          Function evaluations: 346
# ARIMA(0, 1, 4)x(2, 1, 0, 12)12 - AIC:268.65329086340694
# Optimization terminated successfully.
#          Current function value: 2.829516
#          Iterations: 5
#          Function evaluations: 429
# ARIMA(0, 1, 4)x(2, 1, 1, 12)12 - AIC:270.6564026009712
# Optimization terminated successfully.
#          Current function value: 2.829512
#          Iterations: 5
#          Function evaluations: 482
# ARIMA(0, 1, 4)x(2, 1, 2, 12)12 - AIC:272.65612093719307
# Optimization terminated successfully.
#          Current function value: 2.829513
#          Iterations: 5
#          Function evaluations: 535
# ARIMA(0, 1, 4)x(2, 1, 3, 12)12 - AIC:274.6561693376401
# Optimization terminated successfully.
#          Current function value: 2.829513
#          Iterations: 5
#          Function evaluations: 604
# ARIMA(0, 1, 4)x(2, 1, 4, 12)12 - AIC:276.656168576966
# Optimization terminated successfully.
#          Current function value: 2.963081
#          Iterations: 2
#          Function evaluations: 43
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:270.6773163670031
# Optimization terminated successfully.
#          Current function value: 2.929615
#          Iterations: 2
#          Function evaluations: 74
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:269.665317759931
# Optimization terminated successfully.
#          Current function value: 2.916318
#          Iterations: 3
#          Function evaluations: 135
# ARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:270.46861933335504
# Optimization terminated successfully.
#          Current function value: 2.916296
#          Iterations: 3
#          Function evaluations: 169
# ARIMA(1, 1, 0)x(0, 1, 3, 12)12 - AIC:272.4666180226153
# Optimization terminated successfully.
#          Current function value: 2.916290
#          Iterations: 3
#          Function evaluations: 199
# ARIMA(1, 1, 0)x(0, 1, 4, 12)12 - AIC:274.466089543295
# Optimization terminated successfully.
#          Current function value: 2.917394
#          Iterations: 3
#          Function evaluations: 105
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:268.5654755187737
# Optimization terminated successfully.
#          Current function value: 2.916676
#          Iterations: 3
#          Function evaluations: 143
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:270.50079802449545
# Optimization terminated successfully.
#          Current function value: 2.916284
#          Iterations: 3
#          Function evaluations: 166
# ARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:272.4655611125627
# Optimization terminated successfully.
#          Current function value: 2.916283
#          Iterations: 3
#          Function evaluations: 196
# ARIMA(1, 1, 0)x(1, 1, 3, 12)12 - AIC:274.4654598260288
# Optimization terminated successfully.
#          Current function value: 2.916283
#          Iterations: 3
#          Function evaluations: 228
# ARIMA(1, 1, 0)x(1, 1, 4, 12)12 - AIC:276.4654337313592
# Optimization terminated successfully.
#          Current function value: 2.916281
#          Iterations: 3
#          Function evaluations: 124
# ARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:270.46525065927494
# Optimization terminated successfully.
#          Current function value: 2.916280
#          Iterations: 3
#          Function evaluations: 165
# ARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:272.46524043758245
# Optimization terminated successfully.
#          Current function value: 2.916280
#          Iterations: 3
#          Function evaluations: 196
# ARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:274.4652329188606
# Optimization terminated successfully.
#          Current function value: 2.916280
#          Iterations: 3
#          Function evaluations: 230
# ARIMA(1, 1, 0)x(2, 1, 3, 12)12 - AIC:276.46522006947146
# Optimization terminated successfully.
#          Current function value: 2.916280
#          Iterations: 3
#          Function evaluations: 258
# ARIMA(1, 1, 0)x(2, 1, 4, 12)12 - AIC:278.46522335552186
# Optimization terminated successfully.
#          Current function value: 2.963739
#          Iterations: 2
#          Function evaluations: 64
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:272.7365097118402
# Optimization terminated successfully.
#          Current function value: 2.928269
#          Iterations: 3
#          Function evaluations: 138
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:271.5442142747678
# Optimization terminated successfully.
#          Current function value: 2.915490
#          Iterations: 3
#          Function evaluations: 165
# ARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:272.39411242139835
# Optimization terminated successfully.
#          Current function value: 2.915473
#          Iterations: 3
#          Function evaluations: 198
# ARIMA(1, 1, 1)x(0, 1, 3, 12)12 - AIC:274.3925484779647
# Optimization terminated successfully.
#          Current function value: 2.915469
#          Iterations: 3
#          Function evaluations: 227
# ARIMA(1, 1, 1)x(0, 1, 4, 12)12 - AIC:276.3922026235787
# Optimization terminated successfully.
#          Current function value: 2.915962
#          Iterations: 3
#          Function evaluations: 128
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:270.43661349662005
# Optimization terminated successfully.
#          Current function value: 2.915906
#          Iterations: 3
#          Function evaluations: 162
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:272.43151828959316
# Optimization terminated successfully.
#          Current function value: 2.915471
#          Iterations: 3
#          Function evaluations: 194
# ARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:274.3923990745405
# Optimization terminated successfully.
#          Current function value: 2.915471
#          Iterations: 3
#          Function evaluations: 225
# ARIMA(1, 1, 1)x(1, 1, 3, 12)12 - AIC:276.3923674378151
# Optimization terminated successfully.
#          Current function value: 2.915471
#          Iterations: 3
#          Function evaluations: 256
# ARIMA(1, 1, 1)x(1, 1, 4, 12)12 - AIC:278.39235041318796
# Optimization terminated successfully.
#          Current function value: 2.915506
#          Iterations: 3
#          Function evaluations: 160
# ARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:272.3955012340051
# Optimization terminated successfully.
#          Current function value: 2.915468
#          Iterations: 3
#          Function evaluations: 198
# ARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:274.3920822035717
# Optimization terminated successfully.
#          Current function value: 2.915471
#          Iterations: 3
#          Function evaluations: 223
# ARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:276.39234555690194
# Optimization terminated successfully.
#          Current function value: 2.915471
#          Iterations: 3
#          Function evaluations: 254
# ARIMA(1, 1, 1)x(2, 1, 3, 12)12 - AIC:278.3923469125245
# Optimization terminated successfully.
#          Current function value: 2.915471
#          Iterations: 3
#          Function evaluations: 286
# ARIMA(1, 1, 1)x(2, 1, 4, 12)12 - AIC:280.39234636269555
# Optimization terminated successfully.
#          Current function value: 2.911023
#          Iterations: 5
#          Function evaluations: 226
# ARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:269.9921089373852
# Optimization terminated successfully.
#          Current function value: 2.899185
#          Iterations: 5
#          Function evaluations: 276
# ARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:270.9266093980674
# Optimization terminated successfully.
#          Current function value: 2.872428
#          Iterations: 7
#          Function evaluations: 489
# ARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:270.51855497170504
# Optimization terminated successfully.
#          Current function value: 2.872493
#          Iterations: 6
#          Function evaluations: 464
# ARIMA(1, 1, 2)x(0, 1, 3, 12)12 - AIC:272.5243785204566
# Optimization terminated successfully.
#          Current function value: 2.872416
#          Iterations: 6
#          Function evaluations: 524
# ARIMA(1, 1, 2)x(0, 1, 4, 12)12 - AIC:274.5174335840038
# Optimization terminated successfully.
#          Current function value: 2.909280
#          Iterations: 6
#          Function evaluations: 335
# ARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:271.83516464665803
# Optimization terminated successfully.
#          Current function value: 2.875138
#          Iterations: 10
#          Function evaluations: 686
# ARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:270.76245497658135
# Optimization terminated successfully.
#          Current function value: 2.872460
#          Iterations: 6
#          Function evaluations: 462
# ARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:272.52141042653653
# Optimization terminated successfully.
#          Current function value: 2.872449
#          Iterations: 6
#          Function evaluations: 530
# ARIMA(1, 1, 2)x(1, 1, 3, 12)12 - AIC:274.5204237537239
# Optimization terminated successfully.
#          Current function value: 2.872416
#          Iterations: 6
#          Function evaluations: 594
# ARIMA(1, 1, 2)x(1, 1, 4, 12)12 - AIC:276.517399755715
# Optimization terminated successfully.
#          Current function value: 2.908660
#          Iterations: 6
#          Function evaluations: 386
# ARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:273.7794391286907
# Optimization terminated successfully.
#          Current function value: 2.872431
#          Iterations: 6
#          Function evaluations: 444
# ARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:272.51882613051725
# Optimization terminated successfully.
#          Current function value: 2.872432
#          Iterations: 6
#          Function evaluations: 506
# ARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:274.5188537917247
# Optimization terminated successfully.
#          Current function value: 2.872424
#          Iterations: 6
#          Function evaluations: 596
# ARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:276.5181273761002
# Optimization terminated successfully.
#          Current function value: 2.872429
#          Iterations: 5
#          Function evaluations: 528
# ARIMA(1, 1, 2)x(2, 1, 4, 12)12 - AIC:278.5186535191437
# Optimization terminated successfully.
#          Current function value: 2.892018
#          Iterations: 5
#          Function evaluations: 262
# ARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:270.281664611573
# Optimization terminated successfully.
#          Current function value: 2.875605
#          Iterations: 5
#          Function evaluations: 318
# ARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:270.80441504869816
# Optimization terminated successfully.
#          Current function value: 2.857140
#          Iterations: 5
#          Function evaluations: 371
# ARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:271.14258384530217
# Optimization terminated successfully.
#          Current function value: 2.857085
#          Iterations: 5
#          Function evaluations: 425
# ARIMA(1, 1, 3)x(0, 1, 3, 12)12 - AIC:273.1376476537855
# Optimization terminated successfully.
#          Current function value: 2.857018
#          Iterations: 5
#          Function evaluations: 486
# ARIMA(1, 1, 3)x(0, 1, 4, 12)12 - AIC:275.1315808114571
# Optimization terminated successfully.
#          Current function value: 2.867109
#          Iterations: 5
#          Function evaluations: 316
# ARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:270.0397738383577
# Optimization terminated successfully.
#          Current function value: 2.859315
#          Iterations: 6
#          Function evaluations: 435
# ARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:271.33832278355817
# Optimization terminated successfully.
#          Current function value: 2.857015
#          Iterations: 6
#          Function evaluations: 505
# ARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:273.13133291156134
# Optimization terminated successfully.
#          Current function value: 2.857041
#          Iterations: 5
#          Function evaluations: 476
# ARIMA(1, 1, 3)x(1, 1, 3, 12)12 - AIC:275.133657740669
# Optimization terminated successfully.
#          Current function value: 2.857018
#          Iterations: 5
#          Function evaluations: 530
# ARIMA(1, 1, 3)x(1, 1, 4, 12)12 - AIC:277.13164937862797
# Optimization terminated successfully.
#          Current function value: 2.857025
#          Iterations: 5
#          Function evaluations: 356
# ARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:271.13222570737184
# Optimization terminated successfully.
#          Current function value: 2.857024
#          Iterations: 5
#          Function evaluations: 421
# ARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:273.13213885524465
# Optimization terminated successfully.
#          Current function value: 2.857024
#          Iterations: 5
#          Function evaluations: 471
# ARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:275.13212781714475
# Optimization terminated successfully.
#          Current function value: 2.857023
#          Iterations: 5
#          Function evaluations: 522
# ARIMA(1, 1, 3)x(2, 1, 3, 12)12 - AIC:277.13206123552834
# Optimization terminated successfully.
#          Current function value: 2.857022
#          Iterations: 5
#          Function evaluations: 592
# ARIMA(1, 1, 3)x(2, 1, 4, 12)12 - AIC:279.13201818454263
# Optimization terminated successfully.
#          Current function value: 2.852536
#          Iterations: 6
#          Function evaluations: 453
# ARIMA(1, 1, 4)x(0, 1, 0, 12)12 - AIC:268.72822350070555
# Optimization terminated successfully.
#          Current function value: 2.826808
#          Iterations: 6
#          Function evaluations: 520
# ARIMA(1, 1, 4)x(0, 1, 1, 12)12 - AIC:268.41273427659553
# Optimization terminated successfully.
#          Current function value: 2.811758
#          Iterations: 6
#          Function evaluations: 591
# ARIMA(1, 1, 4)x(0, 1, 2, 12)12 - AIC:269.05819423653384
# Optimization terminated successfully.
#          Current function value: 2.805915
#          Iterations: 8
#          Function evaluations: 863
# ARIMA(1, 1, 4)x(0, 1, 3, 12)12 - AIC:270.53236016260985
# Optimization terminated successfully.
#          Current function value: 2.805160
#          Iterations: 7
#          Function evaluations: 840
# ARIMA(1, 1, 4)x(0, 1, 4, 12)12 - AIC:272.46441441859395
# Optimization terminated successfully.
#          Current function value: 2.813050
#          Iterations: 6
#          Function evaluations: 464
# ARIMA(1, 1, 4)x(1, 1, 0, 12)12 - AIC:267.1744947867289
# Optimization terminated successfully.
#          Current function value: 2.808136
#          Iterations: 6
#          Function evaluations: 571
# ARIMA(1, 1, 4)x(1, 1, 1, 12)12 - AIC:268.7322763924187
# Optimization terminated successfully.
#          Current function value: 2.809385
#          Iterations: 6
#          Function evaluations: 635
# ARIMA(1, 1, 4)x(1, 1, 2, 12)12 - AIC:270.84466790317003
# Optimization terminated successfully.
#          Current function value: 2.804440
#          Iterations: 8
#          Function evaluations: 923
# ARIMA(1, 1, 4)x(1, 1, 3, 12)12 - AIC:272.39963794089914
# Optimization terminated successfully.
#          Current function value: 2.804259
#          Iterations: 9
#          Function evaluations: 1127
# ARIMA(1, 1, 4)x(1, 1, 4, 12)12 - AIC:274.38329699229524
# Optimization terminated successfully.
#          Current function value: 2.808690
#          Iterations: 4
#          Function evaluations: 389
# ARIMA(1, 1, 4)x(2, 1, 0, 12)12 - AIC:268.7821392450175
# Optimization terminated successfully.
#          Current function value: 2.808857
#          Iterations: 6
#          Function evaluations: 633
# ARIMA(1, 1, 4)x(2, 1, 1, 12)12 - AIC:270.7970965959931
# Optimization terminated successfully.
#          Current function value: 2.808354
#          Iterations: 6
#          Function evaluations: 695
# ARIMA(1, 1, 4)x(2, 1, 2, 12)12 - AIC:272.75186156663506
# Optimization terminated successfully.
#          Current function value: 2.803890
#          Iterations: 8
#          Function evaluations: 1019
# ARIMA(1, 1, 4)x(2, 1, 3, 12)12 - AIC:274.3500990486629
# Optimization terminated successfully.
#          Current function value: 2.803617
#          Iterations: 9
#          Function evaluations: 1228
# ARIMA(1, 1, 4)x(2, 1, 4, 12)12 - AIC:276.3254896197027
# Optimization terminated successfully.
#          Current function value: 2.963078
#          Iterations: 2
#          Function evaluations: 64
# ARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:272.677030934136
# Optimization terminated successfully.
#          Current function value: 2.927444
#          Iterations: 3
#          Function evaluations: 143
# ARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:271.4699338929115
# Optimization terminated successfully.
#          Current function value: 2.915180
#          Iterations: 3
#          Function evaluations: 166
# ARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:272.3661954844911
# Optimization terminated successfully.
#          Current function value: 2.915163
#          Iterations: 3
#          Function evaluations: 202
# ARIMA(2, 1, 0)x(0, 1, 3, 12)12 - AIC:274.3646524053542
# Optimization terminated successfully.
#          Current function value: 2.915155
#          Iterations: 3
#          Function evaluations: 229
# ARIMA(2, 1, 0)x(0, 1, 4, 12)12 - AIC:276.3639925672384
# Optimization terminated successfully.
#          Current function value: 2.915481
#          Iterations: 3
#          Function evaluations: 127
# ARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:270.39328237136453
# Optimization terminated successfully.
#          Current function value: 2.915370
#          Iterations: 3
#          Function evaluations: 163
# ARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:272.3833308936355
# Optimization terminated successfully.
#          Current function value: 2.915156
#          Iterations: 3
#          Function evaluations: 194
# ARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:274.36401498539254
# Optimization terminated successfully.
#          Current function value: 2.915156
#          Iterations: 3
#          Function evaluations: 225
# ARIMA(2, 1, 0)x(1, 1, 3, 12)12 - AIC:276.3640386388861
# Optimization terminated successfully.
#          Current function value: 2.915156
#          Iterations: 3
#          Function evaluations: 257
# ARIMA(2, 1, 0)x(1, 1, 4, 12)12 - AIC:278.3640500170791
# Optimization terminated successfully.
#          Current function value: 2.915154
#          Iterations: 3
#          Function evaluations: 155
# ARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:272.363826031937
# Optimization terminated successfully.
#          Current function value: 2.915155
#          Iterations: 3
#          Function evaluations: 192
# ARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:274.3639311948806
# Optimization terminated successfully.
#          Current function value: 2.915156
#          Iterations: 3
#          Function evaluations: 224
# ARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:276.36405187865296
# Optimization terminated successfully.
#          Current function value: 2.915156
#          Iterations: 3
#          Function evaluations: 256
# ARIMA(2, 1, 0)x(2, 1, 3, 12)12 - AIC:278.36405384868294
# Optimization terminated successfully.
#          Current function value: 2.915156
#          Iterations: 3
#          Function evaluations: 294
# ARIMA(2, 1, 0)x(2, 1, 4, 12)12 - AIC:280.3640548331716
# Optimization terminated successfully.
#          Current function value: 2.963078
#          Iterations: 2
#          Function evaluations: 90
# ARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:274.67700837604434
# Optimization terminated successfully.
#          Current function value: 2.927384
#          Iterations: 3
#          Function evaluations: 169
# ARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:273.46452688653653
# Optimization terminated successfully.
#          Current function value: 2.915171
#          Iterations: 3
#          Function evaluations: 195
# ARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:274.36542552127116
# Optimization terminated successfully.
#          Current function value: 2.915147
#          Iterations: 3
#          Function evaluations: 230
# ARIMA(2, 1, 1)x(0, 1, 3, 12)12 - AIC:276.3632222708155
# Optimization terminated successfully.
#          Current function value: 2.915142
#          Iterations: 3
#          Function evaluations: 258
# ARIMA(2, 1, 1)x(0, 1, 4, 12)12 - AIC:278.3628226926036
# Optimization terminated successfully.
#          Current function value: 2.915446
#          Iterations: 3
#          Function evaluations: 157
# ARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:272.39011674187316
# Optimization terminated successfully.
#          Current function value: 2.915279
#          Iterations: 3
#          Function evaluations: 184
# ARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:274.3750946426768
# Optimization terminated successfully.
#          Current function value: 2.915158
#          Iterations: 3
#          Function evaluations: 221
# ARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:276.3642557709747
# Optimization terminated successfully.
#          Current function value: 2.915159
#          Iterations: 3
#          Function evaluations: 251
# ARIMA(2, 1, 1)x(1, 1, 3, 12)12 - AIC:278.3642699553849
# Optimization terminated successfully.
#          Current function value: 2.915159
#          Iterations: 3
#          Function evaluations: 283
# ARIMA(2, 1, 1)x(1, 1, 4, 12)12 - AIC:280.3643024916519
# Optimization terminated successfully.
#          Current function value: 2.915123
#          Iterations: 3
#          Function evaluations: 184
# ARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:274.36104638718757
# Optimization terminated successfully.
#          Current function value: 2.915160
#          Iterations: 3
#          Function evaluations: 218
# ARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:276.36440316288224
# Optimization terminated successfully.
#          Current function value: 2.915160
#          Iterations: 3
#          Function evaluations: 247
# ARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:278.36438848515263
# Optimization terminated successfully.
#          Current function value: 2.915160
#          Iterations: 3
#          Function evaluations: 279
# ARIMA(2, 1, 1)x(2, 1, 3, 12)12 - AIC:280.3643862107114
# Optimization terminated successfully.
#          Current function value: 2.915160
#          Iterations: 3
#          Function evaluations: 318
# ARIMA(2, 1, 1)x(2, 1, 4, 12)12 - AIC:282.3643867989759
# Optimization terminated successfully.
#          Current function value: 2.880694
#          Iterations: 12
#          Function evaluations: 639
# ARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:269.26245973687526
# Optimization terminated successfully.
#          Current function value: 2.913658
#          Iterations: 5
#          Function evaluations: 330
# ARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:274.22919057621345
# Optimization terminated successfully.
#          Current function value: 2.831948
#          Iterations: 16
#          Function evaluations: 1233
# ARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:268.87530883814804
# Optimization terminated successfully.
#          Current function value: 2.881438
#          Iterations: 12
#          Function evaluations: 1053
# ARIMA(2, 1, 2)x(0, 1, 3, 12)12 - AIC:275.3293753644291
# Optimization terminated successfully.
#          Current function value: 2.830598
#          Iterations: 13
#          Function evaluations: 1339
# ARIMA(2, 1, 2)x(0, 1, 4, 12)12 - AIC:272.75379399510416
# Optimization terminated successfully.
#          Current function value: 2.905864
#          Iterations: 6
#          Function evaluations: 384
# ARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:273.5277845506049
# Optimization terminated successfully.
#          Current function value: 2.832064
#          Iterations: 9
#          Function evaluations: 678
# ARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:268.8857622520492
# Optimization terminated successfully.
#          Current function value: 2.832238
#          Iterations: 9
#          Function evaluations: 775
# ARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:270.90142502358106
# Optimization terminated successfully.
#          Current function value: 2.831188
#          Iterations: 11
#          Function evaluations: 1097
# ARIMA(2, 1, 2)x(1, 1, 3, 12)12 - AIC:272.8069547784107
# Optimization terminated successfully.
#          Current function value: 2.903501
#          Iterations: 6
#          Function evaluations: 625
# ARIMA(2, 1, 2)x(1, 1, 4, 12)12 - AIC:281.315077271021
# Optimization terminated successfully.
#          Current function value: 2.831749
#          Iterations: 23
#          Function evaluations: 1645
# ARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:268.8574015584286
# Optimization terminated successfully.
#          Current function value: 2.831771
#          Iterations: 10
#          Function evaluations: 860
# ARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:270.85936794037184
# Optimization terminated successfully.
#          Current function value: 2.831659
#          Iterations: 10
#          Function evaluations: 956
# ARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:272.8493252350331
# Optimization terminated successfully.
#          Current function value: 2.831239
#          Iterations: 11
#          Function evaluations: 1205
# ARIMA(2, 1, 2)x(2, 1, 3, 12)12 - AIC:274.811497838166
# Optimization terminated successfully.
#          Current function value: 2.831412
#          Iterations: 10
#          Function evaluations: 1162
# ARIMA(2, 1, 2)x(2, 1, 4, 12)12 - AIC:276.8271188691489
# Optimization terminated successfully.
#          Current function value: 2.897552
#          Iterations: 12
#          Function evaluations: 766
# ARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:272.7796926110814
# Optimization terminated successfully.
#          Current function value: 2.882003
#          Iterations: 8
#          Function evaluations: 627
# ARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:273.3803030641428
# Optimization terminated successfully.
#          Current function value: 2.859496
#          Iterations: 13
#          Function evaluations: 1136
# ARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:273.3546775914331
# Optimization terminated successfully.
#          Current function value: 2.859080
#          Iterations: 13
#          Function evaluations: 1265
# ARIMA(2, 1, 3)x(0, 1, 3, 12)12 - AIC:275.31720791587503
# Optimization terminated successfully.
#          Current function value: 2.849793
#          Iterations: 18
#          Function evaluations: 1958
# ARIMA(2, 1, 3)x(0, 1, 4, 12)12 - AIC:276.4813573724759
# Optimization terminated successfully.
#          Current function value: 2.833976
#          Iterations: 15
#          Function evaluations: 1108
# ARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:269.05785932516847
# Optimization terminated successfully.
#          Current function value: 2.859122
#          Iterations: 9
#          Function evaluations: 790
# ARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:273.32097700008836
# Optimization terminated successfully.
#          Current function value: 2.853403
#          Iterations: 7
#          Function evaluations: 679
# ARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:274.8062470561291
# Optimization terminated successfully.
#          Current function value: 2.849835
#          Iterations: 10
#          Function evaluations: 1079
# ARIMA(2, 1, 3)x(1, 1, 3, 12)12 - AIC:276.4851889887567
# Optimization terminated successfully.
#          Current function value: 2.849665
#          Iterations: 10
#          Function evaluations: 1192
# ARIMA(2, 1, 3)x(1, 1, 4, 12)12 - AIC:278.4698129462249
# Optimization terminated successfully.
#          Current function value: 2.814993
#          Iterations: 19
#          Function evaluations: 1581
# ARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:269.349370486688
# Optimization terminated successfully.
#          Current function value: 2.854546
#          Iterations: 6
#          Function evaluations: 581
# ARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:274.909154350025
# Optimization terminated successfully.
#          Current function value: 2.854411
#          Iterations: 6
#          Function evaluations: 651
# ARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:276.89698995911556
# Optimization terminated successfully.
#          Current function value: 2.849148
#          Iterations: 9
#          Function evaluations: 1066
# ARIMA(2, 1, 3)x(2, 1, 3, 12)12 - AIC:278.4233216818179
# Optimization terminated successfully.
#          Current function value: 2.848299
#          Iterations: 9
#          Function evaluations: 1158
# ARIMA(2, 1, 3)x(2, 1, 4, 12)12 - AIC:280.3469366649533
# Optimization terminated successfully.
#          Current function value: 2.850897
#          Iterations: 13
#          Function evaluations: 1048
# ARIMA(2, 1, 4)x(0, 1, 0, 12)12 - AIC:270.5807437719105
# Optimization terminated successfully.
#          Current function value: 2.824681
#          Iterations: 13
#          Function evaluations: 1202
# ARIMA(2, 1, 4)x(0, 1, 1, 12)12 - AIC:270.2212652233805
# Optimization terminated successfully.
#          Current function value: 2.833155
#          Iterations: 5
#          Function evaluations: 543
# ARIMA(2, 1, 4)x(0, 1, 2, 12)12 - AIC:272.98397200080325
# Optimization terminated successfully.
#          Current function value: 2.833154
#          Iterations: 5
#          Function evaluations: 592
# ARIMA(2, 1, 4)x(0, 1, 3, 12)12 - AIC:274.98383487034357
# Optimization terminated successfully.
#          Current function value: 2.806789
#          Iterations: 14
#          Function evaluations: 1755
# ARIMA(2, 1, 4)x(0, 1, 4, 12)12 - AIC:274.6110447655319
# Optimization terminated successfully.
#          Current function value: 2.835654
#          Iterations: 5
#          Function evaluations: 434
# ARIMA(2, 1, 4)x(1, 1, 0, 12)12 - AIC:271.20890453805663
# Optimization terminated successfully.
#          Current function value: 2.806092
#          Iterations: 15
#          Function evaluations: 1510
# ARIMA(2, 1, 4)x(1, 1, 1, 12)12 - AIC:270.54829490689735
# Optimization terminated successfully.
#          Current function value: 2.833372
#          Iterations: 5
#          Function evaluations: 589
# ARIMA(2, 1, 4)x(1, 1, 2, 12)12 - AIC:275.0035103174349
# Optimization terminated successfully.
#          Current function value: 2.803985
#          Iterations: 16
#          Function evaluations: 1987
# ARIMA(2, 1, 4)x(1, 1, 3, 12)12 - AIC:274.35864165213803
# Optimization terminated successfully.
#          Current function value: 2.805674
#          Iterations: 16
#          Function evaluations: 2124
# ARIMA(2, 1, 4)x(1, 1, 4, 12)12 - AIC:276.51065171482696
# Optimization terminated successfully.
#          Current function value: 2.810046
#          Iterations: 15
#          Function evaluations: 1454
# ARIMA(2, 1, 4)x(2, 1, 0, 12)12 - AIC:270.90416767632195
# Optimization terminated successfully.
#          Current function value: 2.833461
#          Iterations: 5
#          Function evaluations: 582
# ARIMA(2, 1, 4)x(2, 1, 1, 12)12 - AIC:275.0114895755215
# Optimization terminated successfully.
#          Current function value: 2.833373
#          Iterations: 5
#          Function evaluations: 631
# ARIMA(2, 1, 4)x(2, 1, 2, 12)12 - AIC:277.0036117538031
# Optimization terminated successfully.
#          Current function value: 2.810241
#          Iterations: 11
#          Function evaluations: 1443
# ARIMA(2, 1, 4)x(2, 1, 3, 12)12 - AIC:276.92170850252444
# Optimization terminated successfully.
#          Current function value: 2.810432
#          Iterations: 11
#          Function evaluations: 1559
# ARIMA(2, 1, 4)x(2, 1, 4, 12)12 - AIC:278.93886773437237

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_pacf(df_diff)
plot_acf(df_diff)
plt.show()

# %%
train=df[:len(df)*80//100]
test=df[len(df)*80//100:]

# %%
model=sm.tsa.statespace.SARIMAX(train['humidity_min'],order=(0, 1, 4),seasonal_order=(1, 1, 4, 12))
model_fit=model.fit()
predictions=model_fit.predict(start=test.index[0],end=test.index[-1])
test['humidity_min'].plot(figsize=(18,7),legend=True)
predictions.plot(legend=True)
plt.grid()

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(test['humidity_max'],predictions))
# Out:
# 45.253817746897965

# %%
future=pd.DataFrame(pd.date_range("2022-10-01","2023-09-30",freq='MS'),columns=['date'])
future.set_index('date',inplace=True)
Forecast=model_fit.predict(start=future.index[0],end=future.index[-1])

# %%
ax=df['humidity_max'].plot(label="Past Data")
Forecast.plot(ax=ax,label="Predicted Future data",figsize=(18,7))
plt.xlabel("Date")
plt.ylabel("Max Humidity")
plt.legend(["Past","Predicted Future Data"])
plt.grid()
plt.show()
