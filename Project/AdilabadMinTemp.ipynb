# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import itertools
import warnings
from sklearn.metrics import mean_squared_error
warnings.filterwarnings("ignore")

# %%
from pmdarima import auto_arima

# %%
df=pd.read_excel("D:\\DATASETS\\GOAT.xlsx",parse_dates=['date'])

# %%
df.head()
# Out:
#    district       date  rain  temp_min  temp_max  humidity_min  humidity_max  \
# 0  Adilabad 2018-01-01   0.0      10.4      29.7          41.8          83.8
# 1  Adilabad 2018-01-02   0.0      11.2      34.8          29.8          74.6
# 2  Adilabad 2018-01-03   0.0      17.3      38.0          31.8          71.5
# 3  Adilabad 2018-01-04   0.0      27.3      41.0          24.9          75.6
# 4  Adilabad 2018-01-05   0.0      28.7      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
df=df[['date','temp_min']]

# %%
df
# Out:
#            date  temp_min
# 0    2018-01-01      10.4
# 1    2018-01-02      11.2
# 2    2018-01-03      17.3
# 3    2018-01-04      27.3
# 4    2018-01-05      28.7
# ...         ...       ...
# 1729 2022-09-26      22.6
# 1730 2022-09-27      23.9
# 1731 2022-09-28      22.6
# 1732 2022-09-29      23.4
# 1733 2022-09-30      22.1
#
# [1734 rows x 2 columns]

# %%
ndf=df.resample('M',on='date').mean()

# %%
ndf
# Out:
#              temp_min
# date
# 2018-01-31  15.241935
# 2018-02-28  19.053571
# 2018-03-31  21.493548
# 2018-04-30  24.910000
# 2018-05-31  26.441935
# 2018-06-30  24.420000
# 2018-07-31  23.596774
# 2018-08-31  22.738710
# 2018-09-30  22.630000
# 2018-10-31  19.254839
# 2018-11-30  17.050000
# 2018-12-31  14.916129
# 2019-01-31  11.432258
# 2019-02-28  16.307143
# 2019-03-31  21.964516
# 2019-04-30  28.463333
# 2019-05-31  30.770968
# 2019-06-30  29.463333
# 2019-07-31  25.590323
# 2019-08-31  24.954839
# 2019-09-30  24.090000
# 2019-10-31  22.116129
# 2019-11-30  16.640000
# 2019-12-31  14.122581
# 2020-01-31  14.477419
# 2020-02-29  14.758621
# 2020-03-31  19.900000
# 2020-04-30  24.410000
# 2020-05-31  28.458065
# 2020-06-30  26.340000
# 2020-07-31  25.232258
# 2020-08-31  24.658065
# 2020-09-30  24.483333
# 2020-10-31  21.854839
# 2020-11-30  14.483333
# 2020-12-31  10.600000
# 2021-01-31  13.822581
# 2021-02-28  12.221429
# 2021-03-31  18.974194
# 2021-04-30  24.360000
# 2021-05-31  27.454839
# 2021-06-30  24.830000
# 2021-07-31  25.154839
# 2021-08-31  25.138710
# 2021-09-30  24.613333
# 2021-10-31  21.829032
# 2021-11-30  19.303333
# 2021-12-31  13.754839
# 2022-01-31  13.619355
# 2022-02-28  11.214286
# 2022-03-31  21.354839
# 2022-04-30  27.566667
# 2022-05-31  28.812903
# 2022-06-30  27.686667
# 2022-07-31  24.129032
# 2022-08-31  24.135484
# 2022-09-30  23.463333

# %%
ndf.plot(figsize=(18,7))
plt.show()

# %%
adfuller(ndf)
# Out:
# (-1.1191749856938584,
#  0.707364884274003,
#  11,
#  45,
#  {'1%': -3.584828853223594,
#   '5%': -2.9282991495198907,
#   '10%': -2.6023438271604937},
#  203.4460224869649)

# %%
ndf['shift']=ndf.shift()
ndf['shiftdiff']=ndf.temp_min-ndf['shift']
ndf.head()
# Out:
#              temp_min      shift  shiftdiff
# date
# 2018-01-31  15.241935        NaN        NaN
# 2018-02-28  19.053571  15.241935   3.811636
# 2018-03-31  21.493548  19.053571   2.439977
# 2018-04-30  24.910000  21.493548   3.416452
# 2018-05-31  26.441935  24.910000   1.531935

# %%
avg=ndf['shiftdiff'].mean()
ndf['shiftdiff'].replace(np.nan,avg,inplace=True)

# %%
adfuller(ndf['shiftdiff'])
# Out:
# (-3.202134193721715,
#  0.019861475588074762,
#  11,
#  45,
#  {'1%': -3.584828853223594,
#   '5%': -2.9282991495198907,
#   '10%': -2.6023438271604937},
#  201.4861976869625)

# %%
ndf['shiftdiff'].plot(figsize=(18,7))
plt.show()

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf

# %%
plot_acf(ndf['shiftdiff'])
plot_pacf(ndf['shiftdiff'])
plt.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
train=ndf[:len(ndf)*80//100]

# %%
len(train)
# Out:
# 45

# %%
test=ndf[len(ndf)*80//100:]

# %%
len(test)
# Out:
# 12

# %%
model=sm.tsa.arima.ARIMA(train['temp_min'],order=(1,1,2))

# %%
model_fit=model.fit()

# %%
prediction=model_fit.predict(start=test.index[0],end=test.index[-1])

# %%
prediction
# Out:
# 2021-10-31    23.973405
# 2021-11-30    23.242912
# 2021-12-31    22.700781
# 2022-01-31    22.298442
# 2022-02-28    21.999849
# 2022-03-31    21.778250
# 2022-04-30    21.613792
# 2022-05-31    21.491741
# 2022-06-30    21.401161
# 2022-07-31    21.333938
# 2022-08-31    21.284049
# 2022-09-30    21.247024
# Freq: M, Name: predicted_mean, dtype: float64

# %%
test['temp_min'].plot(figsize=(18,7),legend=True)
prediction.plot(legend=True)
# Out:
# <AxesSubplot: xlabel='date'>

# %%
ndf['arimaPred']=prediction

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(test['temp_min'],prediction))
# Out:
# 6.064800665848036

# %%
ndf['diff12']=ndf['temp_min'].diff(12)

# %%
ndf.head()
# Out:
#              temp_min      shift  shiftdiff  arimaPred  diff12
# date
# 2018-01-31  15.241935        NaN   0.146811        NaN     NaN
# 2018-02-28  19.053571  15.241935   3.811636        NaN     NaN
# 2018-03-31  21.493548  19.053571   2.439977        NaN     NaN
# 2018-04-30  24.910000  21.493548   3.416452        NaN     NaN
# 2018-05-31  26.441935  24.910000   1.531935        NaN     NaN

# %%
plot_pacf(ndf['diff12'].dropna())
plot_acf(ndf['diff12'].dropna())
plt.show()

# %%
model=sm.tsa.statespace.SARIMAX(train['temp_min'],order=(1,1,2),seasonal_order=(1,1,4,12))

# %%
model_fit=model.fit()

# %%
predictions=model_fit.predict(start=test.index[0],end=test.index[-1])

# %%
ndf['sarimaPred']=predictions

# %%
predictions
# Out:
# 2021-10-31    22.104206
# 2021-11-30    14.335824
# 2021-12-31    10.351368
# 2022-01-31    14.092207
# 2022-02-28    11.819439
# 2022-03-31    18.306125
# 2022-04-30    23.244634
# 2022-05-31    26.411223
# 2022-06-30    23.611332
# 2022-07-31    24.571070
# 2022-08-31    24.565101
# 2022-09-30    24.167470
# Freq: M, Name: predicted_mean, dtype: float64

# %%
test['temp_min'].plot(figsize=(18,7),legend=True)
predictions.plot(legend=True)
plt.grid()

# %%
np.sqrt(mean_squared_error(test['temp_min'],predictions))
# Out:
# 2.710352014596524

# %%
future=pd.DataFrame(pd.date_range("2022-10-01","2023-09-30",freq='MS'),columns=['date'])

# %%
future
# Out:
#          date
# 0  2022-10-01
# 1  2022-11-01
# 2  2022-12-01
# 3  2023-01-01
# 4  2023-02-01
# 5  2023-03-01
# 6  2023-04-01
# 7  2023-05-01
# 8  2023-06-01
# 9  2023-07-01
# 10 2023-08-01
# 11 2023-09-01

# %%
future.set_index('date',inplace=True)

# %%
future
# Out:
# Empty DataFrame
# Columns: []
# Index: [2022-10-01 00:00:00, 2022-11-01 00:00:00, 2022-12-01 00:00:00, 2023-01-01 00:00:00, 2023-02-01 00:00:00, 2023-03-01 00:00:00, 2023-04-01 00:00:00, 2023-05-01 00:00:00, 2023-06-01 00:00:00, 2023-07-01 00:00:00, 2023-08-01 00:00:00, 2023-09-01 00:00:00]

# %%
Forecast=model_fit.predict(start=future.index[0],end=future.index[-1])

# %%
Forecast
# Out:
# 2022-10-31    21.464553
# 2022-11-30    13.776149
# 2022-12-31     9.668001
# 2023-01-31    13.410226
# 2023-02-28    11.165544
# 2023-03-31    17.528196
# 2023-04-30    22.388937
# 2023-05-31    25.215380
# 2023-06-30    22.341335
# 2023-07-31    23.587240
# 2023-08-31    23.618489
# 2023-09-30    23.206850
# Freq: M, Name: predicted_mean, dtype: float64

# %%
ax=ndf['temp_min'].plot(label="Past Data")
Forecast.plot(ax=ax,label="Predicted Future data",figsize=(18,7))
plt.xlabel("Date")
plt.ylabel("Min_Temp")
plt.legend(["Past","Predicted Future Data"])
plt.grid()
plt.show()
