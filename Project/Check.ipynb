# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_excel("D:\\DATASETS\\GOAT.xlsx",parse_dates=['date'],index_col='date')

# %%
df
# Out:
#             district  rain  temp_min  temp_max  humidity_min  humidity_max  \
# date
# 2018-01-01  Adilabad   0.0      10.4      29.7          41.8          83.8
# 2018-01-02  Adilabad   0.0      11.2      34.8          29.8          74.6
# 2018-01-03  Adilabad   0.0      17.3      38.0          31.8          71.5
# 2018-01-04  Adilabad   0.0      27.3      41.0          24.9          75.6
# 2018-01-05  Adilabad   0.0      28.7      43.2          27.7          48.9
# ...              ...   ...       ...       ...           ...           ...
# 2022-09-26  Adilabad   0.0      22.6      32.7          62.2         100.0
# 2022-09-27  Adilabad   2.3      23.9      33.0          65.2          98.8
# 2022-09-28  Adilabad   4.0      22.6      32.5          70.6         100.0
# 2022-09-29  Adilabad   1.0      23.4      31.6          71.0         100.0
# 2022-09-30  Adilabad   0.0      22.1      30.2          75.8         100.0
#
#             wind_speed_max  wind_speed_min
# date
# ...

# %%
df[['temp_min','temp_max']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['temp_min','humidity_min']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['temp_min','humidity_max']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['temp_min','wind_speed_max']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['temp_min','wind_speed_min']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['temp_min','wind_speed_max']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['temp_min','rain']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['humidity_min','wind_speed_max']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['humidity_min','wind_speed_min']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['wind_speed_min','wind_speed_min']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['humidity_min','rain']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>

# %%
df[['rain','wind_speed_max']].plot(figsize=(18,7))
# Out:
# <AxesSubplot: xlabel='date'>
