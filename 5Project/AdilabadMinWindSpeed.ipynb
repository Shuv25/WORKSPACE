# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import itertools
import warnings
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("D:\\DATASETS\\GOAT.xlsx",parse_dates=['date'])

# %%
df.head()
# Out:
#    district       date  rain  temp_min  temp_max  humidity_min  humidity_max  \
# 0  Adilabad 2018-01-01   0.0      10.4      29.7          41.8          83.8
# 1  Adilabad 2018-01-02   0.0      11.2      34.8          29.8          74.6
# 2  Adilabad 2018-01-03   0.0      17.3      38.0          31.8          71.5
# 3  Adilabad 2018-01-04   0.0      27.3      41.0          24.9          75.6
# 4  Adilabad 2018-01-05   0.0      28.7      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
df=df.resample('M',on='date').mean()

# %%
df
# Out:
#                  rain   temp_min   temp_max  humidity_min  humidity_max  \
# date
# 2018-01-31   1.151613  15.241935  33.187097     40.567742     79.909677
# 2018-02-28   1.350000  19.053571  34.964286     43.907143     80.328571
# 2018-03-31   0.370968  21.493548  36.445161     39.716129     72.570968
# 2018-04-30   0.093333  24.910000  38.920000     37.963333     68.506667
# 2018-05-31   1.532258  26.441935  40.070968     39.064516     71.164516
# 2018-06-30   3.586667  24.420000  35.080000     55.486667     82.226667
# 2018-07-31   6.858065  23.596774  31.577419     65.890323     87.141935
# 2018-08-31   9.422581  22.738710  31.145161     68.932258     92.670968
# 2018-09-30   4.303333  22.630000  33.913333     53.756667     91.666667
# 2018-10-31   1.248387  19.254839  34.141935     46.370968     87.261290
# 2018-11-30   1.586667  17.050000  33.056667     39.866667     89.253333
# 2018-12-31   6.380645  14.916129  29.061290     44.867742     91.606452
# ...

# %%
df['wind_speed_min'].replace(np.nan,0,inplace=True)

# %%
df['wind_speed_min'].plot(figsize=(18,7))
plt.title("Seasonal Pattern of Minimum Wind Speed of Adilabad from 2018 to 2022")
plt.xlabel("Date")
plt.ylabel("Minimum Wind Speed")
plt.legend(['Min Wind Speed'])
plt.show()

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(df['wind_speed_min'], model='additive')
fig = decomposition.plot()
plt.show()

# %%
adfuller(df['wind_speed_min'])
# Out:
# (-3.2914669503628926,
#  0.015264237485025959,
#  1,
#  55,
#  {'1%': -3.5552728880540942,
#   '5%': -2.9157312396694217,
#   '10%': -2.5956695041322315},
#  333.54461521148227)

# %%
'''p = range(0, 3)
d = range(1,2)
q = range(0, 4)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df['wind_speed_min'],
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue'''
# Out:
# "p = range(0, 3)\nd = range(1,2)\nq = range(0, 4)\npdq = list(itertools.product(p, d, q))\nseasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]\n\nfor param in pdq:\n    for param_seasonal in seasonal_pdq:\n        try:\n            mod = sm.tsa.statespace.SARIMAX(df['wind_speed_min'],\n                                            order=param,\n                                            seasonal_order=param_seasonal,\n                                            )\n            results = mod.fit(method = 'powell')\n            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))\n        except:\n            continue"

# %%
train=df[:len(df)*80//100]
test=df[len(df)*80//100:]

# %%
model=sm.tsa.statespace.SARIMAX(train['wind_speed_min'],order=(0,1,1),seasonal_order=(0,1,0,12))

# %%
model_fit=model.fit()
predictions=model_fit.predict(start=test.index[0],end=test.index[-1])

# %%
test['wind_speed_min'].plot(figsize=(18,7),legend=True)
predictions.plot(legend=True)
plt.grid()

# %%
Mean_Squared_Error=np.sqrt(mean_squared_error(test['wind_speed_min'],predictions))

# %%
Mean_Squared_Error
# Out:
# 16.156892150808016

# %%
from sklearn.metrics import mean_absolute_error

# %%
Mean_Absolute_Error=mean_absolute_error(test['wind_speed_min'],predictions)

# %%
Mean_Absolute_Error
# Out:
# 8.236728754707881

# %%
arr1=np.array(Mean_Squared_Error)
arr2=np.array(Mean_Absolute_Error)

# %%
plt.figure(figsize=(10,6))
colors = ['r', 'g']
tick_label=['Mean Sqaured Error','Mean Absolute Error']
plt.bar(['MSE', 'MAE'], [arr1, arr2],tick_label=tick_label,color=colors)
plt.xlabel("Error Type")
plt.ylabel("Error Value")
plt.show()

# %%
future=pd.DataFrame(pd.date_range("2022-10-01","2023-09-30",freq='MS'),columns=['date'])
future.set_index('date',inplace=True)
Forecast=model_fit.predict(start=future.index[0],end=future.index[-1])

# %%
ax=df['wind_speed_min'].plot(label="Actual Past Data")
predictions.plot(ax=ax,label="Prediction on Test data")
Forecast.plot(ax=ax,label="Predicted Future data",figsize=(18,7))
plt.xlabel("Date")
plt.ylabel("Min wind Speed")
plt.legend(["Acual Past data","Prediction on Test data","Predicted Future Data"])
plt.grid()
plt.show()
