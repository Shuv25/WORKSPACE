# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
import itertools
import warnings
from sklearn.metrics import mean_squared_error
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
warnings.filterwarnings("ignore")

# %%
df=pd.read_excel("D:\\DATASETS\\GOAT.xlsx",parse_dates=['date'])

# %%
df.head()
# Out:
#    district       date  rain  temp_min  temp_max  humidity_min  humidity_max  \
# 0  Adilabad 2018-01-01   0.0      10.4      29.7          41.8          83.8
# 1  Adilabad 2018-01-02   0.0      11.2      34.8          29.8          74.6
# 2  Adilabad 2018-01-03   0.0      17.3      38.0          31.8          71.5
# 3  Adilabad 2018-01-04   0.0      27.3      41.0          24.9          75.6
# 4  Adilabad 2018-01-05   0.0      28.7      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
df=df.resample('M',on='date').mean()

# %%
df.head()
# Out:
#                 rain   temp_min   temp_max  humidity_min  humidity_max  \
# date
# 2018-01-31  1.151613  15.241935  33.187097     40.567742     79.909677
# 2018-02-28  1.350000  19.053571  34.964286     43.907143     80.328571
# 2018-03-31  0.370968  21.493548  36.445161     39.716129     72.570968
# 2018-04-30  0.093333  24.910000  38.920000     37.963333     68.506667
# 2018-05-31  1.532258  26.441935  40.070968     39.064516     71.164516
#
#             wind_speed_max  wind_speed_min
# date
# 2018-01-31        0.051613        6.896774
# 2018-02-28        0.007143        6.846429
# 2018-03-31        0.003226        6.293548
# 2018-04-30        0.030000        8.373333
# 2018-05-31        0.296774        9.967742

# %%
df['rain'].plot(figsize=(18,7))
plt.show()

# %%
adfuller(df['rain'])
# Out:
# (-0.2606871468749577,
#  0.9308906078216435,
#  11,
#  45,
#  {'1%': -3.584828853223594,
#   '5%': -2.9282991495198907,
#   '10%': -2.6023438271604937},
#  288.84250825674627)

# %%
df_diff=df['rain'].diff(1).dropna()

# %%
adfuller(df_diff)
# Out:
# (-6.412836870173731,
#  1.872344698293803e-08,
#  11,
#  44,
#  {'1%': -3.5885733964124715,
#   '5%': -2.929885661157025,
#   '10%': -2.6031845661157025},
#  276.41256706048074)

# %%
plot_pacf(df_diff)
plot_acf(df_diff)
plt.show()

# %%
p = range(0, 3)
d = range(1,2)
q = range(0, 5)
pdq = list(itertools.product(p, d, q))
seasonal_pdq = [(x[0], x[1], x[2], 12) for x in list(itertools.product(p, d, q))]

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(df_diff,
                                            order=param,
                                            seasonal_order=param_seasonal,
                                            )
            results = mod.fit(method = 'powell')
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except:
            continue
# Out:
# Optimization terminated successfully.
#          Current function value: 3.063862
#          Iterations: 2
#          Function evaluations: 33
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:345.1525517505292
# Optimization terminated successfully.
#          Current function value: 3.030771
#          Iterations: 3
#          Function evaluations: 73
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:343.4463857952667
# Optimization terminated successfully.
#          Current function value: 3.022610
#          Iterations: 3
#          Function evaluations: 96
# ARIMA(0, 1, 0)x(0, 1, 2, 12)12 - AIC:344.53233459651426
# Optimization terminated successfully.
#          Current function value: 3.009004
#          Iterations: 3
#          Function evaluations: 131
# ARIMA(0, 1, 0)x(0, 1, 3, 12)12 - AIC:345.0084734124378
# Optimization terminated successfully.
#          Current function value: 3.007835
#          Iterations: 3
#          Function evaluations: 158
# ARIMA(0, 1, 0)x(0, 1, 4, 12)12 - AIC:346.8774965405372
# Optimization terminated successfully.
#          Current function value: 3.036632
#          Iterations: 2
#          Function evaluations: 40
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:344.1027886530871
# Optimization terminated successfully.
#          Current function value: 3.028001
#          Iterations: 5
#          Function evaluations: 162
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:345.13608170883134
# Optimization terminated successfully.
#          Current function value: 3.016338
#          Iterations: 5
#          Function evaluations: 228
# ARIMA(0, 1, 0)x(1, 1, 2, 12)12 - AIC:345.82990084891213
# Optimization terminated successfully.
#          Current function value: 3.007854
#          Iterations: 3
#          Function evaluations: 161
# ARIMA(0, 1, 0)x(1, 1, 3, 12)12 - AIC:346.8796774103541
# Optimization terminated successfully.
#          Current function value: 3.007807
#          Iterations: 3
#          Function evaluations: 191
# ARIMA(0, 1, 0)x(1, 1, 4, 12)12 - AIC:348.8743854001984
# Optimization terminated successfully.
#          Current function value: 3.016236
#          Iterations: 3
#          Function evaluations: 90
# ARIMA(0, 1, 0)x(2, 1, 0, 12)12 - AIC:343.8183806310886
# Optimization terminated successfully.
#          Current function value: 3.008043
#          Iterations: 5
#          Function evaluations: 214
# ARIMA(0, 1, 0)x(2, 1, 1, 12)12 - AIC:344.9007959347592
# Optimization terminated successfully.
#          Current function value: 3.007948
#          Iterations: 4
#          Function evaluations: 208
# ARIMA(0, 1, 0)x(2, 1, 2, 12)12 - AIC:346.8901518397215
# Optimization terminated successfully.
#          Current function value: 3.007810
#          Iterations: 3
#          Function evaluations: 184
# ARIMA(0, 1, 0)x(2, 1, 3, 12)12 - AIC:348.87467278945184
# Optimization terminated successfully.
#          Current function value: 3.007807
#          Iterations: 3
#          Function evaluations: 215
# ARIMA(0, 1, 0)x(2, 1, 4, 12)12 - AIC:350.8743976294582
# Optimization terminated successfully.
#          Current function value: 2.650798
#          Iterations: 2
#          Function evaluations: 55
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:300.8894018190586
# Optimization terminated successfully.
#          Current function value: 2.633618
#          Iterations: 2
#          Function evaluations: 77
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:300.96522349433945
# Optimization terminated successfully.
#          Current function value: 2.631104
#          Iterations: 2
#          Function evaluations: 95
# ARIMA(0, 1, 1)x(0, 1, 2, 12)12 - AIC:302.68370028722256
# Optimization terminated successfully.
#          Current function value: 2.622192
#          Iterations: 3
#          Function evaluations: 168
# ARIMA(0, 1, 1)x(0, 1, 3, 12)12 - AIC:303.685522713458
# Optimization terminated successfully.
#          Current function value: 2.622187
#          Iterations: 2
#          Function evaluations: 137
# ARIMA(0, 1, 1)x(0, 1, 4, 12)12 - AIC:305.6849643666314
# Optimization terminated successfully.
#          Current function value: 2.635525
#          Iterations: 2
#          Function evaluations: 75
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:301.1787830797424
# Optimization terminated successfully.
#          Current function value: 2.632855
#          Iterations: 4
#          Function evaluations: 176
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:302.8797158247097
# Optimization terminated successfully.
#          Current function value: 2.633439
#          Iterations: 2
#          Function evaluations: 118
# ARIMA(0, 1, 1)x(1, 1, 2, 12)12 - AIC:304.94514275209536
# Optimization terminated successfully.
#          Current function value: 2.622182
#          Iterations: 3
#          Function evaluations: 202
# ARIMA(0, 1, 1)x(1, 1, 3, 12)12 - AIC:305.6844246278815
# Optimization terminated successfully.
#          Current function value: 2.622184
#          Iterations: 3
#          Function evaluations: 234
# ARIMA(0, 1, 1)x(1, 1, 4, 12)12 - AIC:307.6846391187046
# Optimization terminated successfully.
#          Current function value: 2.629326
#          Iterations: 2
#          Function evaluations: 90
# ARIMA(0, 1, 1)x(2, 1, 0, 12)12 - AIC:302.48449345348337
# Optimization terminated successfully.
#          Current function value: 2.622757
#          Iterations: 6
#          Function evaluations: 329
# ARIMA(0, 1, 1)x(2, 1, 1, 12)12 - AIC:303.74876176605903
# Optimization terminated successfully.
#          Current function value: 2.622184
#          Iterations: 4
#          Function evaluations: 264
# ARIMA(0, 1, 1)x(2, 1, 2, 12)12 - AIC:305.6846631117892
# Optimization terminated successfully.
#          Current function value: 2.622179
#          Iterations: 2
#          Function evaluations: 154
# ARIMA(0, 1, 1)x(2, 1, 3, 12)12 - AIC:307.6840828086847
# Optimization terminated successfully.
#          Current function value: 2.622181
#          Iterations: 2
#          Function evaluations: 174
# ARIMA(0, 1, 1)x(2, 1, 4, 12)12 - AIC:309.68423890794776
# Optimization terminated successfully.
#          Current function value: 2.379393
#          Iterations: 4
#          Function evaluations: 131
# ARIMA(0, 1, 2)x(0, 1, 0, 12)12 - AIC:272.492049517382
# Optimization terminated successfully.
#          Current function value: 2.374350
#          Iterations: 3
#          Function evaluations: 134
# ARIMA(0, 1, 2)x(0, 1, 1, 12)12 - AIC:273.92718590527136
# Optimization terminated successfully.
#          Current function value: 2.374222
#          Iterations: 3
#          Function evaluations: 166
# ARIMA(0, 1, 2)x(0, 1, 2, 12)12 - AIC:275.9128143803501
# Optimization terminated successfully.
#          Current function value: 2.372922
#          Iterations: 3
#          Function evaluations: 199
# ARIMA(0, 1, 2)x(0, 1, 3, 12)12 - AIC:277.7672968534674
# Optimization terminated successfully.
#          Current function value: 2.372939
#          Iterations: 3
#          Function evaluations: 224
# ARIMA(0, 1, 2)x(0, 1, 4, 12)12 - AIC:279.7692216810016
# Optimization terminated successfully.
#          Current function value: 2.374100
#          Iterations: 4
#          Function evaluations: 186
# ARIMA(0, 1, 2)x(1, 1, 0, 12)12 - AIC:273.89918734361663
# Optimization terminated successfully.
#          Current function value: 2.374384
#          Iterations: 3
#          Function evaluations: 164
# ARIMA(0, 1, 2)x(1, 1, 1, 12)12 - AIC:275.93097136289543
# Optimization terminated successfully.
#          Current function value: 2.374328
#          Iterations: 3
#          Function evaluations: 195
# ARIMA(0, 1, 2)x(1, 1, 2, 12)12 - AIC:277.9246935157119
# Optimization terminated successfully.
#          Current function value: 2.372933
#          Iterations: 3
#          Function evaluations: 225
# ARIMA(0, 1, 2)x(1, 1, 3, 12)12 - AIC:279.7685179097148
# Optimization terminated successfully.
#          Current function value: 2.372941
#          Iterations: 3
#          Function evaluations: 256
# ARIMA(0, 1, 2)x(1, 1, 4, 12)12 - AIC:281.76938377995486
# Optimization terminated successfully.
#          Current function value: 2.374193
#          Iterations: 3
#          Function evaluations: 163
# ARIMA(0, 1, 2)x(2, 1, 0, 12)12 - AIC:275.9095847934903
# Optimization terminated successfully.
#          Current function value: 2.374174
#          Iterations: 3
#          Function evaluations: 192
# ARIMA(0, 1, 2)x(2, 1, 1, 12)12 - AIC:277.9075405306134
# Optimization terminated successfully.
#          Current function value: 2.374026
#          Iterations: 3
#          Function evaluations: 224
# ARIMA(0, 1, 2)x(2, 1, 2, 12)12 - AIC:279.89086869187776
# Optimization terminated successfully.
#          Current function value: 2.372934
#          Iterations: 3
#          Function evaluations: 257
# ARIMA(0, 1, 2)x(2, 1, 3, 12)12 - AIC:281.7685750871611
# Optimization terminated successfully.
#          Current function value: 2.372940
#          Iterations: 3
#          Function evaluations: 291
# ARIMA(0, 1, 2)x(2, 1, 4, 12)12 - AIC:283.7693050985199
# Optimization terminated successfully.
#          Current function value: 2.366042
#          Iterations: 3
#          Function evaluations: 186
# ARIMA(0, 1, 3)x(0, 1, 0, 12)12 - AIC:272.99672909831713
# Optimization terminated successfully.
#          Current function value: 2.364793
#          Iterations: 4
#          Function evaluations: 264
# ARIMA(0, 1, 3)x(0, 1, 1, 12)12 - AIC:274.85680482114697
# Optimization terminated successfully.
#          Current function value: 2.364648
#          Iterations: 4
#          Function evaluations: 303
# ARIMA(0, 1, 3)x(0, 1, 2, 12)12 - AIC:276.8405571621323
# Optimization terminated successfully.
#          Current function value: 2.364243
#          Iterations: 4
#          Function evaluations: 353
# ARIMA(0, 1, 3)x(0, 1, 3, 12)12 - AIC:278.7952494438313
# Optimization terminated successfully.
#          Current function value: 2.364247
#          Iterations: 4
#          Function evaluations: 388
# ARIMA(0, 1, 3)x(0, 1, 4, 12)12 - AIC:280.7956268637713
# Optimization terminated successfully.
#          Current function value: 2.364641
#          Iterations: 4
#          Function evaluations: 250
# ARIMA(0, 1, 3)x(1, 1, 0, 12)12 - AIC:274.8397658951534
# Optimization terminated successfully.
#          Current function value: 2.364735
#          Iterations: 4
#          Function evaluations: 310
# ARIMA(0, 1, 3)x(1, 1, 1, 12)12 - AIC:276.8503101955422
# Optimization terminated successfully.
#          Current function value: 2.364685
#          Iterations: 4
#          Function evaluations: 342
# ARIMA(0, 1, 3)x(1, 1, 2, 12)12 - AIC:278.84468442991255
# Optimization terminated successfully.
#          Current function value: 2.364245
#          Iterations: 4
#          Function evaluations: 392
# ARIMA(0, 1, 3)x(1, 1, 3, 12)12 - AIC:280.7954722407819
# Optimization terminated successfully.
#          Current function value: 2.364247
#          Iterations: 4
#          Function evaluations: 434
# ARIMA(0, 1, 3)x(1, 1, 4, 12)12 - AIC:282.79566458393447
# Optimization terminated successfully.
#          Current function value: 2.364699
#          Iterations: 4
#          Function evaluations: 310
# ARIMA(0, 1, 3)x(2, 1, 0, 12)12 - AIC:276.84627711199767
# Optimization terminated successfully.
#          Current function value: 2.364708
#          Iterations: 4
#          Function evaluations: 340
# ARIMA(0, 1, 3)x(2, 1, 1, 12)12 - AIC:278.8472702720333
# Optimization terminated successfully.
#          Current function value: 2.364693
#          Iterations: 4
#          Function evaluations: 380
# ARIMA(0, 1, 3)x(2, 1, 2, 12)12 - AIC:280.8456522967443
# Optimization terminated successfully.
#          Current function value: 2.364247
#          Iterations: 4
#          Function evaluations: 432
# ARIMA(0, 1, 3)x(2, 1, 3, 12)12 - AIC:282.79568698952573
# Optimization terminated successfully.
#          Current function value: 2.364249
#          Iterations: 4
#          Function evaluations: 469
# ARIMA(0, 1, 3)x(2, 1, 4, 12)12 - AIC:284.7958921011716
# Optimization terminated successfully.
#          Current function value: 2.365037
#          Iterations: 3
#          Function evaluations: 213
# ARIMA(0, 1, 4)x(0, 1, 0, 12)12 - AIC:274.8841610304445
# Optimization terminated successfully.
#          Current function value: 2.364198
#          Iterations: 4
#          Function evaluations: 302
# ARIMA(0, 1, 4)x(0, 1, 1, 12)12 - AIC:276.7901590953161
# Optimization terminated successfully.
#          Current function value: 2.363972
#          Iterations: 4
#          Function evaluations: 341
# ARIMA(0, 1, 4)x(0, 1, 2, 12)12 - AIC:278.7648500381142
# Optimization terminated successfully.
#          Current function value: 2.363791
#          Iterations: 4
#          Function evaluations: 381
# ARIMA(0, 1, 4)x(0, 1, 3, 12)12 - AIC:280.7445906586067
# Optimization terminated successfully.
#          Current function value: 2.363792
#          Iterations: 4
#          Function evaluations: 442
# ARIMA(0, 1, 4)x(0, 1, 4, 12)12 - AIC:282.74469694342446
# Optimization terminated successfully.
#          Current function value: 2.363954
#          Iterations: 4
#          Function evaluations: 294
# ARIMA(0, 1, 4)x(1, 1, 0, 12)12 - AIC:276.7628957126088
# Optimization terminated successfully.
#          Current function value: 2.364133
#          Iterations: 4
#          Function evaluations: 345
# ARIMA(0, 1, 4)x(1, 1, 1, 12)12 - AIC:278.78285053474303
# Optimization terminated successfully.
#          Current function value: 2.363997
#          Iterations: 4
#          Function evaluations: 384
# ARIMA(0, 1, 4)x(1, 1, 2, 12)12 - AIC:280.7676631619622
# Optimization terminated successfully.
#          Current function value: 2.363791
#          Iterations: 4
#          Function evaluations: 425
# ARIMA(0, 1, 4)x(1, 1, 3, 12)12 - AIC:282.74455293357545
# Optimization terminated successfully.
#          Current function value: 2.363791
#          Iterations: 4
#          Function evaluations: 474
# ARIMA(0, 1, 4)x(1, 1, 4, 12)12 - AIC:284.74459853026855
# Optimization terminated successfully.
#          Current function value: 2.364011
#          Iterations: 4
#          Function evaluations: 342
# ARIMA(0, 1, 4)x(2, 1, 0, 12)12 - AIC:278.76924756729966
# Optimization terminated successfully.
#          Current function value: 2.364019
#          Iterations: 4
#          Function evaluations: 383
# ARIMA(0, 1, 4)x(2, 1, 1, 12)12 - AIC:280.7701071176843
# Optimization terminated successfully.
#          Current function value: 2.364017
#          Iterations: 4
#          Function evaluations: 422
# ARIMA(0, 1, 4)x(2, 1, 2, 12)12 - AIC:282.7699116770582
# Optimization terminated successfully.
#          Current function value: 2.363792
#          Iterations: 4
#          Function evaluations: 470
# ARIMA(0, 1, 4)x(2, 1, 3, 12)12 - AIC:284.7446845957062
# Optimization terminated successfully.
#          Current function value: 2.363792
#          Iterations: 4
#          Function evaluations: 519
# ARIMA(0, 1, 4)x(2, 1, 4, 12)12 - AIC:286.74470642913445
# Optimization terminated successfully.
#          Current function value: 2.738222
#          Iterations: 2
#          Function evaluations: 50
# ARIMA(1, 1, 0)x(0, 1, 0, 12)12 - AIC:310.68089977425626
# Optimization terminated successfully.
#          Current function value: 2.723574
#          Iterations: 2
#          Function evaluations: 77
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:311.0402716313008
# Optimization terminated successfully.
#          Current function value: 2.720541
#          Iterations: 2
#          Function evaluations: 89
# ARIMA(1, 1, 0)x(0, 1, 2, 12)12 - AIC:312.70061010188823
# Optimization terminated successfully.
#          Current function value: 2.719890
#          Iterations: 2
#          Function evaluations: 109
# ARIMA(1, 1, 0)x(0, 1, 3, 12)12 - AIC:314.62770296385645
# Optimization terminated successfully.
#          Current function value: 2.719896
#          Iterations: 2
#          Function evaluations: 129
# ARIMA(1, 1, 0)x(0, 1, 4, 12)12 - AIC:316.62831005134467
# Optimization terminated successfully.
#          Current function value: 2.721651
#          Iterations: 2
#          Function evaluations: 67
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:310.82488183194783
# Optimization terminated successfully.
#          Current function value: 2.721627
#          Iterations: 2
#          Function evaluations: 92
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:312.8222221046263
# Optimization terminated successfully.
#          Current function value: 2.721564
#          Iterations: 2
#          Function evaluations: 104
# ARIMA(1, 1, 0)x(1, 1, 2, 12)12 - AIC:314.8151972923795
# Optimization terminated successfully.
#          Current function value: 2.719898
#          Iterations: 2
#          Function evaluations: 134
# ARIMA(1, 1, 0)x(1, 1, 3, 12)12 - AIC:316.628600167631
# Optimization terminated successfully.
#          Current function value: 2.719894
#          Iterations: 2
#          Function evaluations: 152
# ARIMA(1, 1, 0)x(1, 1, 4, 12)12 - AIC:318.6281524698943
# Optimization terminated successfully.
#          Current function value: 2.721579
#          Iterations: 2
#          Function evaluations: 91
# ARIMA(1, 1, 0)x(2, 1, 0, 12)12 - AIC:312.81679302653026
# Optimization terminated successfully.
#          Current function value: 2.721580
#          Iterations: 2
#          Function evaluations: 111
# ARIMA(1, 1, 0)x(2, 1, 1, 12)12 - AIC:314.81691098108115
# Optimization terminated successfully.
#          Current function value: 2.720422
#          Iterations: 4
#          Function evaluations: 259
# ARIMA(1, 1, 0)x(2, 1, 2, 12)12 - AIC:316.6872495471815
# Optimization terminated successfully.
#          Current function value: 2.719900
#          Iterations: 2
#          Function evaluations: 155
# ARIMA(1, 1, 0)x(2, 1, 3, 12)12 - AIC:318.62883938655466
# Optimization terminated successfully.
#          Current function value: 2.719896
#          Iterations: 2
#          Function evaluations: 173
# ARIMA(1, 1, 0)x(2, 1, 4, 12)12 - AIC:320.62831326601713
# Optimization terminated successfully.
#          Current function value: 2.489790
#          Iterations: 3
#          Function evaluations: 117
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:284.85646306386747
# Optimization terminated successfully.
#          Current function value: 2.487572
#          Iterations: 3
#          Function evaluations: 139
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:286.6081075615267
# Optimization terminated successfully.
#          Current function value: 2.485896
#          Iterations: 3
#          Function evaluations: 174
# ARIMA(1, 1, 1)x(0, 1, 2, 12)12 - AIC:288.42038381557967
# Optimization terminated successfully.
#          Current function value: 2.485854
#          Iterations: 3
#          Function evaluations: 203
# ARIMA(1, 1, 1)x(0, 1, 3, 12)12 - AIC:290.41570023712956
# Optimization terminated successfully.
#          Current function value: 2.485854
#          Iterations: 3
#          Function evaluations: 234
# ARIMA(1, 1, 1)x(0, 1, 4, 12)12 - AIC:292.4156893136555
# Optimization terminated successfully.
#          Current function value: 2.487107
#          Iterations: 3
#          Function evaluations: 145
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:286.55596455087465
# Optimization terminated successfully.
#          Current function value: 2.487039
#          Iterations: 3
#          Function evaluations: 171
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:288.54839870405283
# Optimization terminated successfully.
#          Current function value: 2.485980
#          Iterations: 3
#          Function evaluations: 207
# ARIMA(1, 1, 1)x(1, 1, 2, 12)12 - AIC:290.4298020417191
# Optimization terminated successfully.
#          Current function value: 2.485854
#          Iterations: 3
#          Function evaluations: 236
# ARIMA(1, 1, 1)x(1, 1, 3, 12)12 - AIC:292.4157008297623
# Optimization terminated successfully.
#          Current function value: 2.485855
#          Iterations: 3
#          Function evaluations: 267
# ARIMA(1, 1, 1)x(1, 1, 4, 12)12 - AIC:294.41570753751824
# Optimization terminated successfully.
#          Current function value: 2.486094
#          Iterations: 3
#          Function evaluations: 177
# ARIMA(1, 1, 1)x(2, 1, 0, 12)12 - AIC:288.4425306190921
# Optimization terminated successfully.
#          Current function value: 2.486096
#          Iterations: 3
#          Function evaluations: 207
# ARIMA(1, 1, 1)x(2, 1, 1, 12)12 - AIC:290.44280125647526
# Optimization terminated successfully.
#          Current function value: 2.486087
#          Iterations: 3
#          Function evaluations: 233
# ARIMA(1, 1, 1)x(2, 1, 2, 12)12 - AIC:292.44178148300404
# Optimization terminated successfully.
#          Current function value: 2.485855
#          Iterations: 3
#          Function evaluations: 263
# ARIMA(1, 1, 1)x(2, 1, 3, 12)12 - AIC:294.4157680226568
# Optimization terminated successfully.
#          Current function value: 2.485855
#          Iterations: 3
#          Function evaluations: 294
# ARIMA(1, 1, 1)x(2, 1, 4, 12)12 - AIC:296.41573913643316
# Optimization terminated successfully.
#          Current function value: 2.365123
#          Iterations: 6
#          Function evaluations: 258
# ARIMA(1, 1, 2)x(0, 1, 0, 12)12 - AIC:272.8937691940378
# Optimization terminated successfully.
#          Current function value: 2.363871
#          Iterations: 6
#          Function evaluations: 311
# ARIMA(1, 1, 2)x(0, 1, 1, 12)12 - AIC:274.7535417332689
# Optimization terminated successfully.
#          Current function value: 2.363641
#          Iterations: 6
#          Function evaluations: 374
# ARIMA(1, 1, 2)x(0, 1, 2, 12)12 - AIC:276.7278246152792
# Optimization terminated successfully.
#          Current function value: 2.363436
#          Iterations: 6
#          Function evaluations: 434
# ARIMA(1, 1, 2)x(0, 1, 3, 12)12 - AIC:278.70484148757544
# Optimization terminated successfully.
#          Current function value: 2.363436
#          Iterations: 6
#          Function evaluations: 495
# ARIMA(1, 1, 2)x(0, 1, 4, 12)12 - AIC:280.7048343173964
# Optimization terminated successfully.
#          Current function value: 2.363803
#          Iterations: 6
#          Function evaluations: 309
# ARIMA(1, 1, 2)x(1, 1, 0, 12)12 - AIC:274.7459465454625
# Optimization terminated successfully.
#          Current function value: 2.363793
#          Iterations: 6
#          Function evaluations: 375
# ARIMA(1, 1, 2)x(1, 1, 1, 12)12 - AIC:276.74478707788097
# Optimization terminated successfully.
#          Current function value: 2.364148
#          Iterations: 4
#          Function evaluations: 300
# ARIMA(1, 1, 2)x(1, 1, 2, 12)12 - AIC:278.78460156131746
# Optimization terminated successfully.
#          Current function value: 2.363436
#          Iterations: 6
#          Function evaluations: 495
# ARIMA(1, 1, 2)x(1, 1, 3, 12)12 - AIC:280.7048385583681
# Optimization terminated successfully.
#          Current function value: 2.363436
#          Iterations: 6
#          Function evaluations: 561
# ARIMA(1, 1, 2)x(1, 1, 4, 12)12 - AIC:282.70483709550206
# Optimization terminated successfully.
#          Current function value: 2.364175
#          Iterations: 4
#          Function evaluations: 258
# ARIMA(1, 1, 2)x(2, 1, 0, 12)12 - AIC:276.78763126462337
# Optimization terminated successfully.
#          Current function value: 2.363698
#          Iterations: 6
#          Function evaluations: 432
# ARIMA(1, 1, 2)x(2, 1, 1, 12)12 - AIC:278.73417525063854
# Optimization terminated successfully.
#          Current function value: 2.363688
#          Iterations: 6
#          Function evaluations: 494
# ARIMA(1, 1, 2)x(2, 1, 2, 12)12 - AIC:280.73303798684435
# Optimization terminated successfully.
#          Current function value: 2.363436
#          Iterations: 6
#          Function evaluations: 554
# ARIMA(1, 1, 2)x(2, 1, 3, 12)12 - AIC:282.7048613385542
# Optimization terminated successfully.
#          Current function value: 2.363436
#          Iterations: 6
#          Function evaluations: 615
# ARIMA(1, 1, 2)x(2, 1, 4, 12)12 - AIC:284.7048585887812
# Optimization terminated successfully.
#          Current function value: 2.370783
#          Iterations: 4
#          Function evaluations: 221
# ARIMA(1, 1, 3)x(0, 1, 0, 12)12 - AIC:275.5276731682852
# Optimization terminated successfully.
#          Current function value: 2.368145
#          Iterations: 4
#          Function evaluations: 267
# ARIMA(1, 1, 3)x(0, 1, 1, 12)12 - AIC:277.23229194160797
# Optimization terminated successfully.
#          Current function value: 2.367797
#          Iterations: 4
#          Function evaluations: 310
# ARIMA(1, 1, 3)x(0, 1, 2, 12)12 - AIC:279.1932298199524
# Optimization terminated successfully.
#          Current function value: 2.367636
#          Iterations: 4
#          Function evaluations: 350
# ARIMA(1, 1, 3)x(0, 1, 3, 12)12 - AIC:281.1752152852415
# Optimization terminated successfully.
#          Current function value: 2.367633
#          Iterations: 4
#          Function evaluations: 393
# ARIMA(1, 1, 3)x(0, 1, 4, 12)12 - AIC:283.17486324527226
# Optimization terminated successfully.
#          Current function value: 2.368633
#          Iterations: 4
#          Function evaluations: 265
# ARIMA(1, 1, 3)x(1, 1, 0, 12)12 - AIC:277.28694513919834
# Optimization terminated successfully.
#          Current function value: 2.367958
#          Iterations: 4
#          Function evaluations: 310
# ARIMA(1, 1, 3)x(1, 1, 1, 12)12 - AIC:279.21124755747877
# Optimization terminated successfully.
#          Current function value: 2.367851
#          Iterations: 4
#          Function evaluations: 348
# ARIMA(1, 1, 3)x(1, 1, 2, 12)12 - AIC:281.1993516158788
# Optimization terminated successfully.
#          Current function value: 2.367637
#          Iterations: 4
#          Function evaluations: 391
# ARIMA(1, 1, 3)x(1, 1, 3, 12)12 - AIC:283.1753377586076
# Optimization terminated successfully.
#          Current function value: 2.367623
#          Iterations: 4
#          Function evaluations: 430
# ARIMA(1, 1, 3)x(1, 1, 4, 12)12 - AIC:285.17380267997993
# Optimization terminated successfully.
#          Current function value: 2.367889
#          Iterations: 4
#          Function evaluations: 306
# ARIMA(1, 1, 3)x(2, 1, 0, 12)12 - AIC:279.20360627081374
# Optimization terminated successfully.
#          Current function value: 2.367889
#          Iterations: 4
#          Function evaluations: 348
# ARIMA(1, 1, 3)x(2, 1, 1, 12)12 - AIC:281.20353338572113
# Optimization terminated successfully.
#          Current function value: 2.367865
#          Iterations: 4
#          Function evaluations: 385
# ARIMA(1, 1, 3)x(2, 1, 2, 12)12 - AIC:283.2008578117465
# Optimization terminated successfully.
#          Current function value: 2.367637
#          Iterations: 4
#          Function evaluations: 440
# ARIMA(1, 1, 3)x(2, 1, 3, 12)12 - AIC:285.17529942229646
# Optimization terminated successfully.
#          Current function value: 2.367623
#          Iterations: 4
#          Function evaluations: 474
# ARIMA(1, 1, 3)x(2, 1, 4, 12)12 - AIC:287.1737216603731
# Optimization terminated successfully.
#          Current function value: 2.365806
#          Iterations: 4
#          Function evaluations: 274
# ARIMA(1, 1, 4)x(0, 1, 0, 12)12 - AIC:276.97021969398764
# Optimization terminated successfully.
#          Current function value: 2.364426
#          Iterations: 4
#          Function evaluations: 311
# ARIMA(1, 1, 4)x(0, 1, 1, 12)12 - AIC:278.81568739207245
# Optimization terminated successfully.
#          Current function value: 2.364216
#          Iterations: 4
#          Function evaluations: 354
# ARIMA(1, 1, 4)x(0, 1, 2, 12)12 - AIC:280.79221625447593
# Optimization terminated successfully.
#          Current function value: 2.363965
#          Iterations: 4
#          Function evaluations: 396
# ARIMA(1, 1, 4)x(0, 1, 3, 12)12 - AIC:282.76403163903035
# Optimization terminated successfully.
#          Current function value: 2.363967
#          Iterations: 4
#          Function evaluations: 437
# ARIMA(1, 1, 4)x(0, 1, 4, 12)12 - AIC:284.76434131029487
# Optimization terminated successfully.
#          Current function value: 2.364260
#          Iterations: 4
#          Function evaluations: 318
# ARIMA(1, 1, 4)x(1, 1, 0, 12)12 - AIC:278.7971443204435
# Optimization terminated successfully.
#          Current function value: 2.364328
#          Iterations: 4
#          Function evaluations: 367
# ARIMA(1, 1, 4)x(1, 1, 1, 12)12 - AIC:280.8047081577161
# Optimization terminated successfully.
#          Current function value: 2.364257
#          Iterations: 4
#          Function evaluations: 398
# ARIMA(1, 1, 4)x(1, 1, 2, 12)12 - AIC:282.7967386315787
# Optimization terminated successfully.
#          Current function value: 2.363967
#          Iterations: 4
#          Function evaluations: 444
# ARIMA(1, 1, 4)x(1, 1, 3, 12)12 - AIC:284.7643116433023
# Optimization terminated successfully.
#          Current function value: 2.363967
#          Iterations: 4
#          Function evaluations: 477
# ARIMA(1, 1, 4)x(1, 1, 4, 12)12 - AIC:286.76425529355
# Optimization terminated successfully.
#          Current function value: 2.364286
#          Iterations: 4
#          Function evaluations: 351
# ARIMA(1, 1, 4)x(2, 1, 0, 12)12 - AIC:280.8000248183782
# Optimization terminated successfully.
#          Current function value: 2.364286
#          Iterations: 4
#          Function evaluations: 398
# ARIMA(1, 1, 4)x(2, 1, 1, 12)12 - AIC:282.79997686464105
# Optimization terminated successfully.
#          Current function value: 2.364268
#          Iterations: 4
#          Function evaluations: 446
# ARIMA(1, 1, 4)x(2, 1, 2, 12)12 - AIC:284.798020220734
# Optimization terminated successfully.
#          Current function value: 2.363967
#          Iterations: 4
#          Function evaluations: 482
# ARIMA(1, 1, 4)x(2, 1, 3, 12)12 - AIC:286.7642533260015
# Optimization terminated successfully.
#          Current function value: 2.363967
#          Iterations: 4
#          Function evaluations: 525
# ARIMA(1, 1, 4)x(2, 1, 4, 12)12 - AIC:288.76425000234536
# Optimization terminated successfully.
#          Current function value: 2.619101
#          Iterations: 2
#          Function evaluations: 68
# ARIMA(2, 1, 0)x(0, 1, 0, 12)12 - AIC:299.3393553290246
# Optimization terminated successfully.
#          Current function value: 2.615101
#          Iterations: 2
#          Function evaluations: 90
# ARIMA(2, 1, 0)x(0, 1, 1, 12)12 - AIC:300.8913515618745
# Optimization terminated successfully.
#          Current function value: 2.614520
#          Iterations: 2
#          Function evaluations: 111
# ARIMA(2, 1, 0)x(0, 1, 2, 12)12 - AIC:302.82626010857985
# Optimization terminated successfully.
#          Current function value: 2.613837
#          Iterations: 2
#          Function evaluations: 132
# ARIMA(2, 1, 0)x(0, 1, 3, 12)12 - AIC:304.74977501159617
# Optimization terminated successfully.
#          Current function value: 2.613821
#          Iterations: 2
#          Function evaluations: 153
# ARIMA(2, 1, 0)x(0, 1, 4, 12)12 - AIC:306.74792807217443
# Optimization terminated successfully.
#          Current function value: 2.614785
#          Iterations: 3
#          Function evaluations: 140
# ARIMA(2, 1, 0)x(1, 1, 0, 12)12 - AIC:300.8559617992756
# Optimization terminated successfully.
#          Current function value: 2.614784
#          Iterations: 2
#          Function evaluations: 109
# ARIMA(2, 1, 0)x(1, 1, 1, 12)12 - AIC:302.85581284984266
# Optimization terminated successfully.
#          Current function value: 2.614706
#          Iterations: 2
#          Function evaluations: 130
# ARIMA(2, 1, 0)x(1, 1, 2, 12)12 - AIC:304.84709136546076
# Optimization terminated successfully.
#          Current function value: 2.613850
#          Iterations: 2
#          Function evaluations: 150
# ARIMA(2, 1, 0)x(1, 1, 3, 12)12 - AIC:306.75125583364667
# Optimization terminated successfully.
#          Current function value: 2.613808
#          Iterations: 2
#          Function evaluations: 170
# ARIMA(2, 1, 0)x(1, 1, 4, 12)12 - AIC:308.7464590570003
# Optimization terminated successfully.
#          Current function value: 2.614768
#          Iterations: 2
#          Function evaluations: 109
# ARIMA(2, 1, 0)x(2, 1, 0, 12)12 - AIC:302.85399098681546
# Optimization terminated successfully.
#          Current function value: 2.614768
#          Iterations: 2
#          Function evaluations: 129
# ARIMA(2, 1, 0)x(2, 1, 1, 12)12 - AIC:304.85399621766146
# Optimization terminated successfully.
#          Current function value: 2.614712
#          Iterations: 2
#          Function evaluations: 151
# ARIMA(2, 1, 0)x(2, 1, 2, 12)12 - AIC:306.8477655718437
# Optimization terminated successfully.
#          Current function value: 2.613849
#          Iterations: 2
#          Function evaluations: 169
# ARIMA(2, 1, 0)x(2, 1, 3, 12)12 - AIC:308.7511332488727
# Optimization terminated successfully.
#          Current function value: 2.613810
#          Iterations: 2
#          Function evaluations: 189
# ARIMA(2, 1, 0)x(2, 1, 4, 12)12 - AIC:310.74668902523854
# Optimization terminated successfully.
#          Current function value: 2.406565
#          Iterations: 3
#          Function evaluations: 144
# ARIMA(2, 1, 1)x(0, 1, 0, 12)12 - AIC:277.53533454646066
# Optimization terminated successfully.
#          Current function value: 2.406283
#          Iterations: 3
#          Function evaluations: 176
# ARIMA(2, 1, 1)x(0, 1, 1, 12)12 - AIC:279.50371286734855
# Optimization terminated successfully.
#          Current function value: 2.406269
#          Iterations: 3
#          Function evaluations: 213
# ARIMA(2, 1, 1)x(0, 1, 2, 12)12 - AIC:281.5021068766167
# Optimization terminated successfully.
#          Current function value: 2.405711
#          Iterations: 3
#          Function evaluations: 237
# ARIMA(2, 1, 1)x(0, 1, 3, 12)12 - AIC:283.4396077653039
# Optimization terminated successfully.
#          Current function value: 2.405706
#          Iterations: 3
#          Function evaluations: 268
# ARIMA(2, 1, 1)x(0, 1, 4, 12)12 - AIC:285.43910999875675
# Optimization terminated successfully.
#          Current function value: 2.406265
#          Iterations: 3
#          Function evaluations: 172
# ARIMA(2, 1, 1)x(1, 1, 0, 12)12 - AIC:279.5016397998932
# Optimization terminated successfully.
#          Current function value: 2.406279
#          Iterations: 3
#          Function evaluations: 207
# ARIMA(2, 1, 1)x(1, 1, 1, 12)12 - AIC:281.50328947411293
# Optimization terminated successfully.
#          Current function value: 2.406275
#          Iterations: 3
#          Function evaluations: 237
# ARIMA(2, 1, 1)x(1, 1, 2, 12)12 - AIC:283.5027872265846
# Optimization terminated successfully.
#          Current function value: 2.405712
#          Iterations: 3
#          Function evaluations: 267
# ARIMA(2, 1, 1)x(1, 1, 3, 12)12 - AIC:285.43968997214813
# Optimization terminated successfully.
#          Current function value: 2.405706
#          Iterations: 3
#          Function evaluations: 299
# ARIMA(2, 1, 1)x(1, 1, 4, 12)12 - AIC:287.43911048119463
# Optimization terminated successfully.
#          Current function value: 2.406278
#          Iterations: 3
#          Function evaluations: 207
# ARIMA(2, 1, 1)x(2, 1, 0, 12)12 - AIC:281.5031231166369
# Optimization terminated successfully.
#          Current function value: 2.406278
#          Iterations: 3
#          Function evaluations: 238
# ARIMA(2, 1, 1)x(2, 1, 1, 12)12 - AIC:283.50312757223384
# Optimization terminated successfully.
#          Current function value: 2.406275
#          Iterations: 3
#          Function evaluations: 268
# ARIMA(2, 1, 1)x(2, 1, 2, 12)12 - AIC:285.5028024916301
# Optimization terminated successfully.
#          Current function value: 2.405711
#          Iterations: 3
#          Function evaluations: 303
# ARIMA(2, 1, 1)x(2, 1, 3, 12)12 - AIC:287.43965501280246
# Optimization terminated successfully.
#          Current function value: 2.405707
#          Iterations: 3
#          Function evaluations: 332
# ARIMA(2, 1, 1)x(2, 1, 4, 12)12 - AIC:289.4391493546492
# Optimization terminated successfully.
#          Current function value: 2.365446
#          Iterations: 10
#          Function evaluations: 562
# ARIMA(2, 1, 2)x(0, 1, 0, 12)12 - AIC:274.9299141199323
# Optimization terminated successfully.
#          Current function value: 2.364067
#          Iterations: 10
#          Function evaluations: 663
# ARIMA(2, 1, 2)x(0, 1, 1, 12)12 - AIC:276.77545449668816
# Optimization terminated successfully.
#          Current function value: 2.363851
#          Iterations: 10
#          Function evaluations: 769
# ARIMA(2, 1, 2)x(0, 1, 2, 12)12 - AIC:278.7513624470504
# Optimization terminated successfully.
#          Current function value: 2.363623
#          Iterations: 10
#          Function evaluations: 877
# ARIMA(2, 1, 2)x(0, 1, 3, 12)12 - AIC:280.7257679844943
# Optimization terminated successfully.
#          Current function value: 2.363530
#          Iterations: 10
#          Function evaluations: 989
# ARIMA(2, 1, 2)x(0, 1, 4, 12)12 - AIC:282.7153048446705
# Optimization terminated successfully.
#          Current function value: 2.364335
#          Iterations: 11
#          Function evaluations: 872
# ARIMA(2, 1, 2)x(1, 1, 0, 12)12 - AIC:276.80548912714596
# Optimization terminated successfully.
#          Current function value: 2.363983
#          Iterations: 10
#          Function evaluations: 778
# ARIMA(2, 1, 2)x(1, 1, 1, 12)12 - AIC:278.7660625521926
# Optimization terminated successfully.
#          Current function value: 2.363893
#          Iterations: 10
#          Function evaluations: 865
# ARIMA(2, 1, 2)x(1, 1, 2, 12)12 - AIC:280.75597180237304
# Optimization terminated successfully.
#          Current function value: 2.363618
#          Iterations: 10
#          Function evaluations: 966
# ARIMA(2, 1, 2)x(1, 1, 3, 12)12 - AIC:282.7252052328817
# Optimization terminated successfully.
#          Current function value: 2.363538
#          Iterations: 10
#          Function evaluations: 1085
# ARIMA(2, 1, 2)x(1, 1, 4, 12)12 - AIC:284.7162862314498
# Optimization terminated successfully.
#          Current function value: 2.363899
#          Iterations: 10
#          Function evaluations: 765
# ARIMA(2, 1, 2)x(2, 1, 0, 12)12 - AIC:278.7567115486234
# Optimization terminated successfully.
#          Current function value: 2.363908
#          Iterations: 10
#          Function evaluations: 864
# ARIMA(2, 1, 2)x(2, 1, 1, 12)12 - AIC:280.7577390099728
# Optimization terminated successfully.
#          Current function value: 2.363847
#          Iterations: 10
#          Function evaluations: 970
# ARIMA(2, 1, 2)x(2, 1, 2, 12)12 - AIC:282.7508554047559
# Optimization terminated successfully.
#          Current function value: 2.363612
#          Iterations: 10
#          Function evaluations: 1081
# ARIMA(2, 1, 2)x(2, 1, 3, 12)12 - AIC:284.7245934663463
# Optimization terminated successfully.
#          Current function value: 2.363673
#          Iterations: 10
#          Function evaluations: 1184
# ARIMA(2, 1, 2)x(2, 1, 4, 12)12 - AIC:286.7313784636596
# Optimization terminated successfully.
#          Current function value: 2.365087
#          Iterations: 6
#          Function evaluations: 406
# ARIMA(2, 1, 3)x(0, 1, 0, 12)12 - AIC:276.8897022386911
# Optimization terminated successfully.
#          Current function value: 2.363968
#          Iterations: 6
#          Function evaluations: 465
# ARIMA(2, 1, 3)x(0, 1, 1, 12)12 - AIC:278.76445434388444
# Optimization terminated successfully.
#          Current function value: 2.363751
#          Iterations: 6
#          Function evaluations: 527
# ARIMA(2, 1, 3)x(0, 1, 2, 12)12 - AIC:280.7401234715279
# Optimization terminated successfully.
#          Current function value: 2.363512
#          Iterations: 6
#          Function evaluations: 598
# ARIMA(2, 1, 3)x(0, 1, 3, 12)12 - AIC:282.713373459129
# Optimization terminated successfully.
#          Current function value: 2.363502
#          Iterations: 6
#          Function evaluations: 650
# ARIMA(2, 1, 3)x(0, 1, 4, 12)12 - AIC:284.7122349856276
# Optimization terminated successfully.
#          Current function value: 2.363918
#          Iterations: 6
#          Function evaluations: 455
# ARIMA(2, 1, 3)x(1, 1, 0, 12)12 - AIC:278.75876846923995
# Optimization terminated successfully.
#          Current function value: 2.363887
#          Iterations: 6
#          Function evaluations: 525
# ARIMA(2, 1, 3)x(1, 1, 1, 12)12 - AIC:280.7553605202471
# Optimization terminated successfully.
#          Current function value: 2.363784
#          Iterations: 6
#          Function evaluations: 588
# ARIMA(2, 1, 3)x(1, 1, 2, 12)12 - AIC:282.74386053807706
# Optimization terminated successfully.
#          Current function value: 2.363509
#          Iterations: 6
#          Function evaluations: 652
# ARIMA(2, 1, 3)x(1, 1, 3, 12)12 - AIC:284.7130370275572
# Optimization terminated successfully.
#          Current function value: 2.363503
#          Iterations: 6
#          Function evaluations: 716
# ARIMA(2, 1, 3)x(1, 1, 4, 12)12 - AIC:286.71229765552823
# Optimization terminated successfully.
#          Current function value: 2.363817
#          Iterations: 6
#          Function evaluations: 525
# ARIMA(2, 1, 3)x(2, 1, 0, 12)12 - AIC:280.7474746017138
# Optimization terminated successfully.
#          Current function value: 2.363814
#          Iterations: 6
#          Function evaluations: 588
# ARIMA(2, 1, 3)x(2, 1, 1, 12)12 - AIC:282.7471877955936
# Optimization terminated successfully.
#          Current function value: 2.363790
#          Iterations: 6
#          Function evaluations: 646
# ARIMA(2, 1, 3)x(2, 1, 2, 12)12 - AIC:284.7445349513454
# Optimization terminated successfully.
#          Current function value: 2.363513
#          Iterations: 6
#          Function evaluations: 719
# ARIMA(2, 1, 3)x(2, 1, 3, 12)12 - AIC:286.71341974328135
# Optimization terminated successfully.
#          Current function value: 2.363505
#          Iterations: 6
#          Function evaluations: 777
# ARIMA(2, 1, 3)x(2, 1, 4, 12)12 - AIC:288.71254967330185
# Optimization terminated successfully.
#          Current function value: 2.330544
#          Iterations: 15
#          Function evaluations: 1195
# ARIMA(2, 1, 4)x(0, 1, 0, 12)12 - AIC:275.0209118827956
# Optimization terminated successfully.
#          Current function value: 2.331995
#          Iterations: 18
#          Function evaluations: 1593
# ARIMA(2, 1, 4)x(0, 1, 1, 12)12 - AIC:277.18344958454185
# Optimization terminated successfully.
#          Current function value: 2.361362
#          Iterations: 7
#          Function evaluations: 705
# ARIMA(2, 1, 4)x(0, 1, 2, 12)12 - AIC:282.4725424710646
# Optimization terminated successfully.
#          Current function value: 2.330199
#          Iterations: 12
#          Function evaluations: 1366
# ARIMA(2, 1, 4)x(0, 1, 3, 12)12 - AIC:280.9823216717674
# Optimization terminated successfully.
#          Current function value: 2.323120
#          Iterations: 15
#          Function evaluations: 1817
# ARIMA(2, 1, 4)x(0, 1, 4, 12)12 - AIC:282.1894507745309
# Optimization terminated successfully.
#          Current function value: 2.331362
#          Iterations: 16
#          Function evaluations: 1417
# ARIMA(2, 1, 4)x(1, 1, 0, 12)12 - AIC:277.11253449620057
# Optimization terminated successfully.
#          Current function value: 2.361634
#          Iterations: 7
#          Function evaluations: 714
# ARIMA(2, 1, 4)x(1, 1, 1, 12)12 - AIC:282.5029913595383
# Optimization terminated successfully.
#          Current function value: 2.361243
#          Iterations: 7
#          Function evaluations: 778
# ARIMA(2, 1, 4)x(1, 1, 2, 12)12 - AIC:284.4592628210487
# Optimization terminated successfully.
#          Current function value: 2.330195
#          Iterations: 12
#          Function evaluations: 1487
# ARIMA(2, 1, 4)x(1, 1, 3, 12)12 - AIC:282.9818421595052
# Optimization terminated successfully.
#          Current function value: 2.322701
#          Iterations: 17
#          Function evaluations: 2461
# ARIMA(2, 1, 4)x(1, 1, 4, 12)12 - AIC:284.1425401272743
# Optimization terminated successfully.
#          Current function value: 2.361124
#          Iterations: 7
#          Function evaluations: 704
# ARIMA(2, 1, 4)x(2, 1, 0, 12)12 - AIC:282.44589514635373
# Optimization terminated successfully.
#          Current function value: 2.361071
#          Iterations: 7
#          Function evaluations: 773
# ARIMA(2, 1, 4)x(2, 1, 1, 12)12 - AIC:284.43997386690063
# Optimization terminated successfully.
#          Current function value: 2.361075
#          Iterations: 7
#          Function evaluations: 851
# ARIMA(2, 1, 4)x(2, 1, 2, 12)12 - AIC:286.44043543886266
# Optimization terminated successfully.
#          Current function value: 2.330131
#          Iterations: 12
#          Function evaluations: 1609
# ARIMA(2, 1, 4)x(2, 1, 3, 12)12 - AIC:284.9747220636828
# Optimization terminated successfully.
#          Current function value: 2.322337
#          Iterations: 17
#          Function evaluations: 2552
# ARIMA(2, 1, 4)x(2, 1, 4, 12)12 - AIC:286.1017395023838

# %%
df_diff2=df['rain'].diff(12)

# %%
plot_pacf(df_diff2)
plot_acf(df_diff2)
plt.show()

# %%
train=df[:len(df)*80//100]
test=df[len(df)*80//100:]

# %%
model=sm.tsa.statespace.SARIMAX(train['rain'],order=(18, 0, 1),seasonal_order=(0, 1, 0, 12))
model_fit=model.fit()
predictions=model_fit.predict(start=test.index[0],end=test.index[-1])
test['rain'].plot(figsize=(18,7),legend=True)
predictions.plot(legend=True)
plt.grid()

# %%
np.sqrt(mean_squared_error(test['rain'],predictions))
# Out:
# 7.14003880349449

# %%
future=pd.DataFrame(pd.date_range("2022-10-01","2023-09-30",freq='MS'),columns=['date'])
future.set_index('date',inplace=True)
Forecast=model_fit.predict(start=future.index[0],end=future.index[-1])

# %%
ax=df['rain'].plot(label="Past Data")
Forecast.plot(ax=ax,label="Predicted Future data",figsize=(18,7))
plt.xlabel("Date")
plt.ylabel("Rain")
plt.legend(["Past","Predicted Future Data"])
plt.grid()
plt.show()
