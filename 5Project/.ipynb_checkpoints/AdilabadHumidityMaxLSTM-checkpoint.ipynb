# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt
from datetime import datetime
from keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint, TensorBoard
# %matplotlib inline

# %%
dataset_train = pd.read_excel("D:\\DATASETS\\GOAT.xlsx")

# %%
dataset_train.head()
# Out:
#    district       date  rain  temp_min  temp_max  humidity_min  humidity_max  \
# 0  Adilabad 2018-01-01   0.0      10.4      29.7          41.8          83.8
# 1  Adilabad 2018-01-02   0.0      11.2      34.8          29.8          74.6
# 2  Adilabad 2018-01-03   0.0      17.3      38.0          31.8          71.5
# 3  Adilabad 2018-01-04   0.0      27.3      41.0          24.9          75.6
# 4  Adilabad 2018-01-05   0.0      28.7      43.2          27.7          48.9
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
del dataset_train['district']

# %%
f_col=dataset_train.pop('humidity_max')

# %%
dataset_train.insert(1,'humidity_max',f_col)

# %%
dataset_train.head(5)
# Out:
#         date  humidity_max  rain  temp_min  temp_max  humidity_min  \
# 0 2018-01-01          83.8   0.0      10.4      29.7          41.8
# 1 2018-01-02          74.6   0.0      11.2      34.8          29.8
# 2 2018-01-03          71.5   0.0      17.3      38.0          31.8
# 3 2018-01-04          75.6   0.0      27.3      41.0          24.9
# 4 2018-01-05          48.9   0.0      28.7      43.2          27.7
#
#    wind_speed_max  wind_speed_min
# 0             0.0             5.7
# 1             0.0             4.8
# 2             0.0             3.4
# 3             0.0             7.7
# 4             0.0            13.5

# %%
mode=dataset_train['wind_speed_min'].value_counts().idxmax()
dataset_train['wind_speed_min'].replace(np.nan,mode,inplace=True)

# %%
# Select features (columns) to be involved intro training and predictions
cols = list(dataset_train)[1:]

# Extract dates (will be used in visualization)
datelist_train = list(dataset_train['date'])

# %%
print('Training set shape == {}'.format(dataset_train.shape))
print('All timestamps == {}'.format(len(datelist_train)))
print('Featured selected: {}'.format(cols))
# Out:
# Training set shape == (1734, 8)
# All timestamps == 1734
# Featured selected: ['humidity_max', 'rain', 'temp_min', 'temp_max', 'humidity_min', 'wind_speed_max', 'wind_speed_min']

# %%
dataset_train = dataset_train[cols].astype(str)
dataset_train = dataset_train.astype(float)
training_set = dataset_train.values
print('Shape of training set == {}.'.format(training_set.shape))
# Out:
# Shape of training set == (1734, 7).

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler

sc = StandardScaler()
training_set_scaled = sc.fit_transform(training_set)

sc_predict = StandardScaler()
sc_predict.fit_transform(training_set[:, 0:1])
# Out:
# array([[ 0.08670815],
#        [-0.39351603],
#        [-0.5553307 ],
#        ...,
#        [ 0.93232028],
#        [ 0.93232028],
#        [ 0.93232028]])

# %%
# Creating a data structure with 90 timestamps and 1 output
X_train = []
y_train = []

n_future = 365   # Number of days we want top predict into the future
n_past = 550    # Number of past days we want to use to predict the future

for i in range(n_past, len(training_set_scaled) - n_future +1):
    X_train.append(training_set_scaled[i - n_past:i, 0:dataset_train.shape[1] - 1])
    y_train.append(training_set_scaled[i + n_future - 1:i + n_future, 0])

X_train, y_train = np.array(X_train), np.array(y_train)

print('X_train shape == {}.'.format(X_train.shape))
print('y_train shape == {}.'.format(y_train.shape))
# Out:
# X_train shape == (820, 550, 6).
# y_train shape == (820, 1).

# %%
# Import Libraries and packages from Keras
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout
from keras.optimizers import Adam

# %%
# Initializing the Neural Network based on LSTM
model = Sequential()

# Adding 1st LSTM layer
model.add(LSTM(units=64, return_sequences=True, input_shape=(n_past, dataset_train.shape[1]-1)))

# Adding 2nd LSTM layer
model.add(LSTM(units=10, return_sequences=False))

# Adding Dropout
model.add(Dropout(0.25))

# Output layer
model.add(Dense(units=1, activation='linear'))

# Compiling the Neural Network
model.compile(optimizer = Adam(learning_rate=0.01), loss='mean_squared_error')

# %%
# %%time
es = EarlyStopping(monitor='val_loss', min_delta=1e-10, patience=10, verbose=1)
rlr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=10, verbose=1)
mcp = ModelCheckpoint(filepath='weights.h5', monitor='val_loss', verbose=1, save_best_only=True, save_weights_only=True)

tb = TensorBoard('logs')

history = model.fit(X_train, y_train, shuffle=True, epochs=30, callbacks=[es, rlr, mcp, tb], validation_split=0.2, verbose=1, batch_size=256)
# Out:
# Epoch 1/30
# 3/3 [==============================] - ETA: 0s - loss: 0.5823
# Epoch 1: val_loss improved from inf to 0.31477, saving model to weights.h5
# 3/3 [==============================] - 32s 6s/step - loss: 0.5823 - val_loss: 0.3148 - lr: 0.0100
# Epoch 2/30
# 3/3 [==============================] - ETA: 0s - loss: 0.4848
# Epoch 2: val_loss improved from 0.31477 to 0.30401, saving model to weights.h5
# 3/3 [==============================] - 12s 4s/step - loss: 0.4848 - val_loss: 0.3040 - lr: 0.0100
# Epoch 3/30
# 3/3 [==============================] - ETA: 0s - loss: 0.4616
# Epoch 3: val_loss improved from 0.30401 to 0.24948, saving model to weights.h5
# 3/3 [==============================] - 13s 4s/step - loss: 0.4616 - val_loss: 0.2495 - lr: 0.0100
# Epoch 4/30
# 3/3 [==============================] - ETA: 0s - loss: 0.4494
# Epoch 4: val_loss did not improve from 0.24948
# 3/3 [==============================] - 12s 4s/step - loss: 0.4494 - val_loss: 0.2816 - lr: 0.0100
# Epoch 5/30
# 3/3 [==============================] - ETA: 0s - loss: 0.4035
# Epoch 5: val_loss did not improve from 0.24948
# 3/3 [==============================] - 15s 5s/step - loss: 0.4035 - val_loss: 0.2511 - lr: 0.0100
# Epoch 6/30
# 3/3 [==============================] - ETA: 0s - loss: 0.4010
# Epoch 6: val_loss improved from 0.24948 to 0.20253, saving model to weights.h5
# 3/3 [==============================] - 15s 5s/step - loss: 0.4010 - val_loss: 0.2025 - lr: 0.0100
# Epoch 7/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3671
# Epoch 7: val_loss did not improve from 0.20253
# 3/3 [==============================] - 18s 6s/step - loss: 0.3671 - val_loss: 0.2137 - lr: 0.0100
# Epoch 8/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3667
# Epoch 8: val_loss improved from 0.20253 to 0.19045, saving model to weights.h5
# 3/3 [==============================] - 14s 4s/step - loss: 0.3667 - val_loss: 0.1904 - lr: 0.0100
# Epoch 9/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3749
# Epoch 9: val_loss improved from 0.19045 to 0.17221, saving model to weights.h5
# 3/3 [==============================] - 13s 4s/step - loss: 0.3749 - val_loss: 0.1722 - lr: 0.0100
# Epoch 10/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3639
# Epoch 10: val_loss improved from 0.17221 to 0.16359, saving model to weights.h5
# 3/3 [==============================] - 13s 4s/step - loss: 0.3639 - val_loss: 0.1636 - lr: 0.0100
# Epoch 11/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3571
# Epoch 11: val_loss did not improve from 0.16359
# 3/3 [==============================] - 15s 5s/step - loss: 0.3571 - val_loss: 0.1642 - lr: 0.0100
# Epoch 12/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3325
# Epoch 12: val_loss improved from 0.16359 to 0.15745, saving model to weights.h5
# 3/3 [==============================] - 16s 5s/step - loss: 0.3325 - val_loss: 0.1574 - lr: 0.0100
# Epoch 13/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3394
# Epoch 13: val_loss did not improve from 0.15745
# 3/3 [==============================] - 14s 5s/step - loss: 0.3394 - val_loss: 0.1808 - lr: 0.0100
# Epoch 14/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3172
# Epoch 14: val_loss did not improve from 0.15745
# 3/3 [==============================] - 14s 5s/step - loss: 0.3172 - val_loss: 0.1644 - lr: 0.0100
# Epoch 15/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3253
# Epoch 15: val_loss improved from 0.15745 to 0.14521, saving model to weights.h5
# 3/3 [==============================] - 16s 6s/step - loss: 0.3253 - val_loss: 0.1452 - lr: 0.0100
# Epoch 16/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3767
# Epoch 16: val_loss improved from 0.14521 to 0.14504, saving model to weights.h5
# 3/3 [==============================] - 18s 5s/step - loss: 0.3767 - val_loss: 0.1450 - lr: 0.0100
# Epoch 17/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3663
# Epoch 17: val_loss did not improve from 0.14504
# 3/3 [==============================] - 18s 6s/step - loss: 0.3663 - val_loss: 0.2381 - lr: 0.0100
# Epoch 18/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3763
# Epoch 18: val_loss did not improve from 0.14504
# 3/3 [==============================] - 15s 5s/step - loss: 0.3763 - val_loss: 0.1861 - lr: 0.0100
# Epoch 19/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3666
# Epoch 19: val_loss improved from 0.14504 to 0.14237, saving model to weights.h5
# 3/3 [==============================] - 16s 5s/step - loss: 0.3666 - val_loss: 0.1424 - lr: 0.0100
# Epoch 20/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3437
# Epoch 20: val_loss did not improve from 0.14237
# 3/3 [==============================] - 17s 5s/step - loss: 0.3437 - val_loss: 0.1531 - lr: 0.0100
# Epoch 21/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3690
# Epoch 21: val_loss improved from 0.14237 to 0.14102, saving model to weights.h5
# 3/3 [==============================] - 15s 5s/step - loss: 0.3690 - val_loss: 0.1410 - lr: 0.0100
# Epoch 22/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3595
# Epoch 22: val_loss did not improve from 0.14102
# 3/3 [==============================] - 16s 5s/step - loss: 0.3595 - val_loss: 0.1536 - lr: 0.0100
# Epoch 23/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3282
# Epoch 23: val_loss did not improve from 0.14102
# 3/3 [==============================] - 20s 6s/step - loss: 0.3282 - val_loss: 0.1774 - lr: 0.0100
# Epoch 24/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3034
# Epoch 24: val_loss did not improve from 0.14102
# 3/3 [==============================] - 17s 5s/step - loss: 0.3034 - val_loss: 0.1638 - lr: 0.0100
# Epoch 25/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2595
# Epoch 25: val_loss did not improve from 0.14102
# 3/3 [==============================] - 13s 4s/step - loss: 0.2595 - val_loss: 0.1565 - lr: 0.0100
# Epoch 26/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2818
# Epoch 26: val_loss did not improve from 0.14102
# 3/3 [==============================] - 13s 4s/step - loss: 0.2818 - val_loss: 0.1572 - lr: 0.0100
# Epoch 27/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2624
# Epoch 27: val_loss did not improve from 0.14102
# 3/3 [==============================] - 14s 5s/step - loss: 0.2624 - val_loss: 0.2848 - lr: 0.0100
# Epoch 28/30
# 3/3 [==============================] - ETA: 0s - loss: 0.3610
# Epoch 28: val_loss did not improve from 0.14102
# 3/3 [==============================] - 14s 4s/step - loss: 0.3610 - val_loss: 0.1766 - lr: 0.0100
# Epoch 29/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2452
# Epoch 29: val_loss improved from 0.14102 to 0.13588, saving model to weights.h5
# 3/3 [==============================] - 13s 4s/step - loss: 0.2452 - val_loss: 0.1359 - lr: 0.0100
# Epoch 30/30
# 3/3 [==============================] - ETA: 0s - loss: 0.2488
# Epoch 30: val_loss improved from 0.13588 to 0.13402, saving model to weights.h5
# 3/3 [==============================] - 16s 6s/step - loss: 0.2488 - val_loss: 0.1340 - lr: 0.0100
# CPU times: total: 17min 21s
# Wall time: 7min 44s

# %%
# Generate list of sequence of days for predictions
datelist_future = pd.date_range(datelist_train[-1], periods=n_future, freq='1d').tolist()

# Convert Pandas Timestamp to Datetime object (for transformation) --> FUTURE
datelist_future_ = []
for this_timestamp in datelist_future:
    datelist_future_.append(this_timestamp.date())

# %%
# Perform predictions
predictions_future = model.predict(X_train[-n_future:])

predictions_train = model.predict(X_train[n_past:])
# Out:
# 12/12 [==============================] - 8s 386ms/step
# 9/9 [==============================] - 3s 346ms/step

# %%
def datetime_to_timestamp(x):
    return datetime.strptime(x.strftime('%Y%m%d'), '%Y%m%d')

# %%
y_pred_future = sc_predict.inverse_transform(predictions_future)
y_pred_train = sc_predict.inverse_transform(predictions_train)

PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['humidity_max']).set_index(pd.Series(datelist_future))
PREDICTION_TRAIN = pd.DataFrame(y_pred_train, columns=['humidity_max']).set_index(pd.Series(datelist_train[2 *n_past +n_future -1:]))

# %%
PREDICTION_TRAIN.index = PREDICTION_TRAIN.index.to_series().apply(datetime_to_timestamp)

PREDICTION_TRAIN
# Out:
#             humidity_max
# 2022-01-04     94.363068
# 2022-01-05     94.451973
# 2022-01-06     94.380905
# 2022-01-07     94.535522
# 2022-01-08     94.817406
# ...                  ...
# 2022-09-26     97.665657
# 2022-09-27     98.424316
# 2022-09-28     99.395241
# 2022-09-29     98.081070
# 2022-09-30     96.992294
#
# [270 rows x 1 columns]

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(dataset_train['humidity_max'][1464:],PREDICTION_TRAIN))
# Out:
# 7.161333991422446

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(dataset_train['humidity_max'][1464:],PREDICTION_TRAIN)
# Out:
# 5.168489507039388

# %%
dataset_train.index=datelist_train

# %%
dataset_train.head(5)
# Out:
#             humidity_max  rain  temp_min  temp_max  humidity_min  \
# 2018-01-01          83.8   0.0      10.4      29.7          41.8
# 2018-01-02          74.6   0.0      11.2      34.8          29.8
# 2018-01-03          71.5   0.0      17.3      38.0          31.8
# 2018-01-04          75.6   0.0      27.3      41.0          24.9
# 2018-01-05          48.9   0.0      28.7      43.2          27.7
#
#             wind_speed_max  wind_speed_min
# 2018-01-01             0.0             5.7
# 2018-01-02             0.0             4.8
# 2018-01-03             0.0             3.4
# 2018-01-04             0.0             7.7
# 2018-01-05             0.0            13.5

# %%
ax=dataset_train['humidity_max']["2022-01-04":"2022-09-30"].plot(figsize=(18,7))
PREDICTION_TRAIN.plot(ax=ax)
plt.legend(['Actual','Predicted'],prop={'size':15})
plt.grid()
plt.show()

# %%
PREDICTIONS_FUTURE.plot(color='green',figsize=(18,6))
plt.xlabel("Date")
plt.ylabel("Max Humidity")
plt.legend(['Future Forecast'],prop={'size':15})
plt.grid()
plt.show()

# %%
PREDICTIONS_FUTURE.to_excel("AdilabadMaxHumidityUsingLSTM.xlsx")

# %%
ax=dataset_train['humidity_max']["2022-01-04":"2022-09-30"].plot(figsize=(18,7))
PREDICTION_TRAIN.plot(ax=ax)
PREDICTIONS_FUTURE.plot(ax=ax)
plt.legend(['Actual','Predicted','Future'],prop={'size':15})
plt.grid()
plt.show()
