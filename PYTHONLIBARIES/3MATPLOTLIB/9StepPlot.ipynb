# %%
import  matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5]
y=[1,2,3,4,5]

plt.step(x,y,color='r',marker="*",ms=10,mfc='y',label='Python')
plt.title("Step Plot")
plt.xlabel("x-axis")
plt.ylabel("y-axis")

plt.legend()
plt.grid()
plt.show()
