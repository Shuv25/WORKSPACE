# %%
import pandas as pd

# %%
df=pd.read_csv("D:\\DATASETS\\Employee.csv")
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0           NaN         2017  Bangalore          3.0   34    Male          No
# 1     Bachelors         2013       Pune          1.0   28  Female          No
# 2     Bachelors         2014        NaN          3.0   38  Female         NaN
# 3       Masters         2016  Bangalore          3.0   27    Male          No
# 4       Masters         2017       Pune          3.0   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore          3.0   26  Female          No
# 4649    Masters         2013       Pune          2.0   37    Male          No
# 4650    Masters         2018  New Delhi          3.0   27    Male          No
# 4651  Bachelors         2012  Bangalore          3.0   30    Male         Yes
# 4652  Bachelors         2015  Bangalore          3.0   33    Male         Yes
#
# ...

# %%
#df.dropna()#by default it will delete the rows

# %%
#df.dropna(axis=1)#will delete column wise

# %%
#df.dropna(subset=['Education'])#only remove the null value of an particular column

# %%
df.dropna(inplace=True)#will delete the all null values

# %%
df
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 1     Bachelors         2013       Pune          1.0   28  Female          No
# 3       Masters         2016  Bangalore          3.0   27    Male          No
# 5     Bachelors         2016  Bangalore          3.0   22    Male          No
# 6     Bachelors         2015  New Delhi          3.0   38    Male          No
# 8     Bachelors         2016       Pune          3.0   23    Male          No
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore          3.0   26  Female          No
# 4649    Masters         2013       Pune          2.0   37    Male          No
# 4650    Masters         2018  New Delhi          3.0   27    Male          No
# 4651  Bachelors         2012  Bangalore          3.0   30    Male         Yes
# 4652  Bachelors         2015  Bangalore          3.0   33    Male         Yes
#
# ...

# %%
#df.dropna(thresh=1)#will dlete the ony columns that has only one null value

# %% [markdown]
# Fiina

# %%
#df.fillna("Python")#to fill al the  null values with python

# %%
#df.fillna({'Education':'C++','City':'Java','EverBenched':'PHP'})#we can fill any particular column null vaues with any value
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0           C++         2017  Bangalore          3.0   34    Male          No
# 1     Bachelors         2013       Pune          1.0   28  Female          No
# 2     Bachelors         2014       Java          3.0   38  Female         PHP
# 3       Masters         2016  Bangalore          3.0   27    Male          No
# 4       Masters         2017       Pune          3.0   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore          3.0   26  Female          No
# 4649    Masters         2013       Pune          2.0   37    Male          No
# 4650    Masters         2018  New Delhi          3.0   27    Male          No
# 4651  Bachelors         2012  Bangalore          3.0   30    Male         Yes
# 4652  Bachelors         2015  Bangalore          3.0   33    Male         Yes
#
# ...

# %%
#df.fillna(method='ffill')#will fill the value with forward value

# %%
#df.fillna(method='bfill')#will fill the value with bckord value

# %%
#df.fillna(66,inplace=True)#will fill all the nan value with 66

# %%
df.fillna('C++',limit=3)#it will fill up to 3 nana value columns only
