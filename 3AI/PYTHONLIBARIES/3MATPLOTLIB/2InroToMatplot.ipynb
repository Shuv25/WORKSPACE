# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Line Plot

# %%
x=[3,4,5,6]
y=[3,4,5,6]

plt.plot(x,y)
plt.show()

# %% [markdown]
# Bar Plot

# %%
c=['r','y','g','b']
plt.bar(x,y,color=c)
plt.show()
