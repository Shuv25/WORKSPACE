# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
x=[3,4,5,6]
y=[3,4,8,7]

plt.stem(x,y,linefmt=':',basefmt='g',markerfmt='ro',label='Python',use_line_collection=False)

plt.legend()
plt.show()
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_4188\149132663.py:4: MatplotlibDeprecationWarning: The 'use_line_collection' parameter of stem() was deprecated in Matplotlib 3.6 and will be removed two minor releases later. If any parameter follows 'use_line_collection', they should be passed as keyword, not positionally.
#   plt.stem(x,y,linefmt=':',basefmt='g',markerfmt='ro',label='Python',use_line_collection=False)
